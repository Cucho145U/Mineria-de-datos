# %% [markdown]
# # Bibliotecas usadas

# %%
import numpy as np
import pandas as pd
from itertools import combinations

# %% [markdown]
# # Leer datos

# %%
datos = np.load('spotify.npy', encoding = "latin1",allow_pickle="False") # Cargar archivo

# %% [markdown]
# ## Ordenamos las listas de reproduccion dentro de un arreglo

# %%
playlists=[]
for i in datos.item():
    datos.item()[i].sort()
    playlists.append(list((set(datos.item()[i]))))

# %% [markdown]
# ### Mostramos los datos

# %%
playlists
# Out:
# [['Toxic',
#   'Livin on Sunday',
#   "Jumpin', Jumpin'",
#   'Soak Up The Sun',
#   'Replay',
#   'The Great Escape',
#   'Party In The U.S.A.',
#   'Everytime We Touch - Radio Edit',
#   'Your Love Is My Drug',
#   'Somebody To Love',
#   'Baby',
#   'Beep',
#   'Check On It - feat. Bun B and Slim Thug',
#   'Forever',
#   'Ice Box',
#   'Me & U',
#   'My Boo',
#   'Crazy In Love',
#   'Right Where You Want Me - Radio Edit Version',
#   'Mr. Brightside',
#   'Paper Planes',
#   'Year 3000',
#   "Leavin'",
#   'Sk8er Boi',
#   'Where Is The Love?',
#   'Dirty Little Secret',
#   'My Happy Ending',
#   'Rock Your Body',
#   'All The Small Things',
#   "It Wasn't Me",
#   'This Is Me',
#   'Just The Girl',
#   "Stacy's Mom",
#   'Promiscuous',
#   'Say My Name',
#   'Yo (Excuse Me Miss)',
#   'A Thousand Miles',
#   'Buttons',
#   'How Do You Sleep? - Featuring Ludacris',
#   'Run It!',
#   'Check Yes Juliet',
#   'Lip Gloss',
#   'Miss Independent',
#   'One Less Lonely Girl',
#   'Lose Control (feat. Ciara & Fat Man Scoop)',
#   'Beautiful Soul',
#   'Whatcha Say',
#   'Yeah!',
#   'See You Again',
#   'Closer',
#   'Hey Ya! - Radio Mix / Club Mix'],
#  ['To The Fair',
#   'No Matter What/Wolf Chase - Reprise',
#   'Long Ago...',
#   'The Gospel Truth I / Main Titles - Hercules',
#   'Destrucción Del Agora',
#   'High Adventure',
#   'Sure As Sun Turns to Moon (Reprise) - Broadway Cast Recording',
#   'Genie And Jasmine/Cassim Leaves',
#   "If I Can't Love Her",
#   'Babkak, Omar, Aladdin, Kassim',
#   'You\'re Only Second Rate - From "The Return of Jafar" / Soundtrack Version',
#   "I'm Looking Out For Me (The Return Of Jafar)",
#   'Happy End In Agrabah',
#   'One Step Closer - Broadway Cast Recording',
#   'Go the Distance (Reprise)',
#   'Beauty and the Beast - Duet with Peabo Bryson from the Soundtrack "Beauty and the Beast"',
#   'Who Better Than Me? (Reprise) - Broadway Cast Recording',
#   'For The First Time - Broadway Cast Recording',
#   'Go the Distance - From "Hercules"/Soundtrack',
#   'Daughters Of Triton - Broadway Cast Recording',
#   'The Oracle',
#   "I Won't Say (I'm in Love)",
#   'Belle Reprise - Soundtrack',
#   'Poor Unfortunate Souls (Reprise) - Broadway Cast Recording',
#   'Forget About Love (The Return Of Jafar)',
#   'Proud of Your Boy',
#   'Act One Finale',
#   'Poor Unfortunate Souls - Broadway Cast Recording',
#   'A True Hero / A Star Is Born',
#   'A Million Miles Away',
#   'Two Worlds - Phil Version',
#   'West Wing',
#   'Out Of Thin Air',
#   'Sure As Sun Turns to Moon - Broadway Cast Recording',
#   'Zero To Hero',
#   'The Ends Of The Earth',
#   "Somebody's Got Your Back",
#   'The Contest - Broadway Cast Recording',
#   "A Whole New World (Aladdin's Theme)",
#   'Beyond My Wildest Dreams - Broadway Cast Recording',
#   'I Want the Good Times Back - Broadway Cast Recording',
#   'Me',
#   'Son of Man - Broadway Cast Recording',
#   'Arabian Nights',
#   'End Duet / Transformation',
#   'If Only (Reprise) - Broadway Cast Recording',
#   'Prologue: Beauty And The Beast - Soundtrack',
#   'Everything That I Am - Broadway Cast Recording',
#   'Daughters of Triton - From "The Little Mermaid"/ Soundtrack Version',
#   'Gaston - From "Beauty and the Beast" / Soundtrack Version',
#   'Welcome To The Forty Thieves',
#   'Maison Des Lunes',
#   'Go the Distance',
#   'On A Dark Night',
#   'Are You In Or Out?',
#   'Prince Ali (Sultan Reprise)',
#   "She's in Love - Broadway Cast Recording",
#   'Overture - Broadway Cast Recording',
#   'Kiss the Girl - Broadway Cast Recording',
#   'La Profecia',
#   'La Isla De Fil',
#   'Under the Sea (Reprise) - Broadway Cast Recording',
#   'A Star Is Born',
#   'Genie Medley',
#   'Human Stuff - Broadway Cast Recording',
#   'Part of Your World - From "The Little Mermaid"/ Soundtrack Version',
#   'Hablando Del Rey De Tebas',
#   'The Gospel Truth III',
#   'Waiting For This Moment - Broadway Cast Recording',
#   'Be Our Guest',
#   'Gaston (Reprise)',
#   'Arabian Nights Reprise',
#   'Kiss the Girl',
#   'Prince Ali',
#   "You'll Be In My Heart",
#   'No Matter What',
#   'The Hand Of Midas',
#   'One Jump Ahead (Reprise)',
#   'The Gospel Truth II',
#   'One Last Hope',
#   'The Batalla Con La Hidra',
#   'Dark Mountain/The Challenge',
#   "You'll Be In My Heart (Reprise) - Broadway Cast Recording",
#   'Belle',
#   'Under the Sea - From "The Little Mermaid"/ Soundtrack Version',
#   'Part Of Your World',
#   'Gaston',
#   'The Beast Lets Belle Go',
#   'Poor Unfortunate Souls - From "The Little Mermaid" / Soundtrack Version',
#   'Zeus Todopoderoso',
#   'Happy Ending - From "The Little Mermaid"/ Soundtrack Version',
#   'Belle - Reprise',
#   'Beauty And The Beast',
#   'Different - Broadway Cast Recording',
#   "Like No Man I've Ever Seen - Broadway Cast Recording",
#   'Finale - Broadway Cast Recording',
#   'Cortando La Hebra',
#   'Beauty And The Beast (Reprise)',
#   'Positoovity - Broadway Cast Recording',
#   'A Whole New World',
#   'Who Better Than Me - Broadway Cast Recording',
#   'Street Urchins',
#   'Diamond in the Rough',
#   'Rodeo',
#   'Part of Your World (Reprise) - From "The Little Mermaid"/ Soundtrack Version',
#   'Father And Son',
#   'Prince Ali (Jafar Reprise)',
#   'If Only (Quartet) - Broadway Cast Recording',
#   "Aladdin's World",
#   'Human Again',
#   'The Battle',
#   'Magic Carpet/Parting The Seas',
#   'The Mob Song',
#   "You'll Be In My Heart - Broadway Cast Recording",
#   'Strangers Like Me - Broadway Cast Recording',
#   'The World Above (Reprise) - Broadway Cast Recording',
#   'Finale Ultimo',
#   'Proud of Your Boy (Reprise)',
#   'Be Our Guest - From "Beauty and the Beast"/Soundtrack',
#   'One Jump Ahead',
#   'Kiss the Girl - From "The Little Mermaid"/Soundtrack Version',
#   'Sweet Child - Broadway Cast Recording',
#   'Gaston - Reprise',
#   'Friend Like Me',
#   'Beauty and the Beast',
#   'Under the Sea - Broadway Cast Recording',
#   'Marketplace',
#   'Alley Talk/Guards Chase Aladdin',
#   'End Credits (Aladdin And The King Of Thieves)',
#   'An Unusual Prince/Once Upon A Dream - From "Sleeping Beauty"/Soundtrack Version',
#   'Sweet Child (Reprise) - Broadway Cast Recording',
#   'Two Worlds (Finale) - Broadway Cast Recording',
#   'Jasmine Runs Away',
#   'La Gran Aceituna',
#   'I Need to Know - Broadway Cast Recording',
#   'El Más Mentecato',
#   'To Be Free',
#   'These Palace Walls',
#   "Jafar's Hour",
#   'Transformation',
#   "If I Can't Love Her - Reprise",
#   "Entr'Acte/Wolf Chase",
#   'Prologue (The Enchantress)',
#   'Prince Ali (Reprise)',
#   "Trashin' The Camp - Broadway Cast Recording",
#   'The World Above - Broadway Cast Recording',
#   'No Other Way - Broadway Cast Recording',
#   'The Mob Song - Soundtrack',
#   'Home',
#   'I Want the Good Times Back (Reprise) - Broadway Cast Recording',
#   'Wedding/Attack Of The Forty Thieves',
#   'Something There',
#   'Two Worlds Reprise',
#   'El Jardín De Meg',
#   'La Villa De Hércules',
#   'Storm at Sea - Broadway Cast Recording',
#   "There's A Party Here In Agrabah, Part II",
#   'Two Worlds Finale',
#   'Legend Of The Lamp',
#   'The Cave Of Wonders',
#   'Overture',
#   'How Long Must This Go On?',
#   'Son Of Man',
#   'The Kiss',
#   'Battle On The Tower',
#   'Aladdin And Cassim Escape',
#   'Two Worlds',
#   'Fathoms Below - Broadway Cast Recording',
#   'Part Of Your World (Reprise) - Broadway Cast Recording',
#   "There's A Party Here In Agrabah, Part I",
#   'Her Voice - Broadway Cast Recording',
#   'Main Title - The Little Mermaid - From "The Little Mermaid"/ Score',
#   'Home - Reprise'],
#  ['Black Betty',
#   'I Wish',
#   'Kick Out The Epic Motherf**ker',
#   "While I Was Playin' Fair",
#   'Snow (Hey Oh) - Hey Oh Album Version',
#   'Hey Brother',
#   'You & Me - Flume Remix',
#   'Hindsight',
#   'Young Americans - 2016 Remastered Version',
#   'Stronger',
#   'ABC',
#   'The Next Episode',
#   'One Touch',
#   'Down The Road',
#   'Free Bird',
#   'Never Say Goodbye - Radio Edit',
#   'Tuna Melt',
#   'Ass Like That',
#   'Do It Again',
#   'Acid Raindrops',
#   'Fame - 2016 Remastered Version',
#   'Feels Like the First Time - 2008 Remastered Version',
#   'Gecko (Overdrive) - Extended',
#   'Aeroplane',
#   'Lean On (feat. MØ & DJ Snake)',
#   'Cocaine Blues',
#   'Rambo - Hardwell Edit',
#   'Ten Crack Commandments - 2014 Remastered Version',
#   'Half Full Glass Of Wine',
#   'Hyperparadise - Flume Mixtape Version',
#   'Symphonica - Original Mix',
#   "I'm Good",
#   'No Role Modelz',
#   'Without Me',
#   'Dirt Off Your Shoulder',
#   'We Own the Night (feat. Luciana) [Original Mix]',
#   'The Message',
#   'Billie Jean',
#   'Guns Are Drawn',
#   'Bohemian Rhapsody - Remastered 2011',
#   "Can't You Hear Me Knocking - Remastered",
#   'Feed The Dada - 2015 Remix',
#   'New Lands',
#   'Two Princes',
#   'More Than a Feeling',
#   'Around The World / Harder Better Faster Stronger',
#   'Epsilon - Original Mix',
#   'You Sexy Thing',
#   'Hoohah',
#   'Boy Oh Boy',
#   'Good Vibrations',
#   'Give It Away',
#   'Foreplay / Long Time',
#   'Basket Case',
#   'High You Are',
#   'Black River Killer',
#   'Kiss Kiss',
#   'Mirror Maru',
#   'No Type',
#   "She's Got Me Dancing",
#   'Adore',
#   'Feel The Volume',
#   'New Girl',
#   'Party Up - GTA Remix',
#   'U Guessed It (Remix)',
#   'Bricks',
#   'Teenage Crime - Axwell & Henrik B Remode',
#   "We'll Be Ok",
#   "Won't Get Fooled Again - Remix",
#   'Pour Some Sugar On Me (2012)',
#   'Amazing',
#   'Cold As Ice - Single / LP Version',
#   "Jessie's Girl",
#   'Juicy',
#   'Okay',
#   "We Won't Go Home - Jane Doze Remix",
#   'Seven Nation Army',
#   'Disco Inferno',
#   'Insane - L D R U Remix',
#   'Point/Counterpoint',
#   'Peace Frog',
#   "Moar Ghosts 'n' Stuff",
#   'The Light - Club Mix',
#   'Pour Some Sugar on Me',
#   'Hella Hoes',
#   'Eyes On Fire - Zeds Dead Remix',
#   '1985',
#   'The W.A.N.D.',
#   'My Friends Never Die',
#   "Don't Stop Believin'",
#   'Changes',
#   'Werewolves Of London - 2007 Remastered Version',
#   'Peanut Butter Jelly',
#   'Me and Julio Down by the Schoolyard',
#   "Life's Been Good",
#   'Rollup - Baauer Remix',
#   'Left Hand Free - Lido Remix',
#   'Jailhouse',
#   'Jaguar',
#   'Feel The Love - feat. John Newman [Fred V & Grafix Remix]',
#   'Fitzpleasure',
#   'Roxanne - Remastered 2003',
#   'Play That Funky Music',
#   'Sympathy For The Devil',
#   'Happy Violence',
#   'Every Other Freckle',
#   'Shine - Kygo Remix',
#   'Feed The Dada',
#   'Survival Tactics (feat. Capital Steez)',
#   "Ain't Nobody (Loves Me Better)",
#   'Gimme Shelter',
#   'Somebody To Love - Remastered 2011',
#   'Renegade',
#   'Sun Models',
#   'Dumb Disco Ideas',
#   "Every 1's A Winner",
#   'HyperParadise - Flume Remix (Ganz Flip)',
#   'My Name Is',
#   'Recess (feat. Fatman Scoop and Michael Angelakos) - Milo And Otis Remix',
#   'Kiss',
#   'Express Yourself',
#   'How We Do - Radio Edit',
#   'Animals - Extended',
#   'Big Poppa',
#   'Get Down Tonight - 2004 Remastered Version',
#   'Turn up the Speakers - Original Mix',
#   'White Noise / Red Meat - Radio Edit',
#   'Work REMIX',
#   'Heads Will Roll - A-Trak Remix',
#   'Hypnotize - 2014 Remastered Version',
#   'Runaway (U & I) - Kaskade Remix',
#   'World Domination',
#   'Make You Mine (Radio Edit)',
#   'White Lies',
#   'Bap U',
#   'Doses & Mimosas',
#   'Paradise Awaits',
#   'So Lonely - Remastered 2003',
#   'Hot Blooded',
#   'Clash',
#   'Gotta Get Away',
#   'Man Of The Year',
#   'Take Over Control - Radio Edit',
#   "I'm Doin' My Thang",
#   'In Time - Singularity Remix',
#   'So Ruff, So Tuff',
#   'Officer',
#   'Sweet Emotion',
#   'My Band',
#   'Ignition - Remix',
#   'Bend Ova'],
#  ['Should’ve Been Us - DubVision Remix',
#   'What Is Love 2016 - Mike Mago Remix',
#   "I'll Take You - Solidisco Remix",
#   'The Party (This Is How We Do It)',
#   'Hold Me Up - AM2PM Remix',
#   'Better off That Way - Radio Mix',
#   'Down for U - Radio Mix',
#   'I Will Be Here - (Wolfgang Gartner Remix)',
#   'Love Me Now - Dave Audé Remix Radio Edit',
#   'Strike It Up',
#   'I Love You Always Forever',
#   'Never Forget You (Future House Remix)',
#   'Show Me Love (Radio Edit)',
#   'Closer - Wuki Remix',
#   'Thinkin of U',
#   "Ain't No Mountain High Enough - Radio Edit"],
#  ['Ghost to Me (Bonus Track)',
#   'Best Night',
#   "Oh! Sweet Nuthin' - 2015 Remastered",
#   'Drug Mugger',
#   'Raspberry Cane',
#   'Please, Please, Please - Live At The Apollo Theater/1967',
#   'Pleasure Point',
#   'Little Town Flirt',
#   'After Laughter (Comes Tears)',
#   'Time Of The Season (Mono Version)',
#   'Diarabi',
#   "Darlin'",
#   'Egg Raid On Mojo',
#   'How You Doin, Here We Go',
#   'Same Thing All Over',
#   'Till We Meet Again',
#   'Marea Baja',
#   'Back At The Farm',
#   'Wintersong',
#   'Out On The Tiles',
#   'What Difference Does It Make? - John Peel session 5/18/83',
#   "You Don't Love Me",
#   'Good Morning Judge',
#   'The Big Ship - 2004 Digital Remaster',
#   'One Way Out - Live At The Fillmore East/1971',
#   'Disco Fever',
#   'Ramble Tamble',
#   'The Mingle',
#   'White Lies, Yellow Teeth',
#   'Filler',
#   'Chaos Engine',
#   'Hiroshima',
#   'Whiskeyclone, Hotel City 1997',
#   'Liquid Swords',
#   'Everyone Who Pretended To Like Me Is Gone',
#   'The Thing',
#   'Over And Done With',
#   "Nothin' In the World Can Stop Me Worryin' 'Bout That Girl",
#   'Los Angeles',
#   'Wild Witch',
#   'Gut Feeling',
#   'Betray',
#   'Children of the Grave - Remastered Version',
#   'Stumped',
#   'Planet of the Dreamers',
#   'Ebb Tide',
#   'Bluebirds Over The Mountain',
#   'Levitate Me',
#   'Born to Lose',
#   'Sun Sinking Low',
#   "Death of a Ladies' Man",
#   'Merchandise - Demo',
#   'Road To Nowhere - 2005 Remastered Version',
#   'Snakes And Martyrs',
#   'Summertime',
#   'Talk To God',
#   'Holland, 1945',
#   'White Trash Heroes',
#   'Jean-Baptiste à la fenêtre',
#   'Staring at the Sun',
#   'Brendan 1',
#   'Circles',
#   'The Bully',
#   'Come and Get Your Love',
#   'Egg Raid On Mojo - Demo',
#   'Breakthrough',
#   'Tundra/Desert',
#   'Black Water'],
#  ["I Don't Need To Know",
#   'Georgia',
#   'Toxic',
#   'Like Real People Do',
#   'Sleep Baby Sleep',
#   'You Could Be Happy',
#   'Beach Baby',
#   'Re:Stacks',
#   'Faux',
#   'New Soul',
#   'Trouble',
#   'Run - Revised Album Version',
#   "You've Haunted Me All My Life",
#   'I Will Follow You Into The Dark',
#   'Little Wanderer',
#   'Pretty When You Cry',
#   'How to Save a Life',
#   'Menswear',
#   'Bloom - Bonus Track',
#   'Facing West',
#   'Going To California',
#   'Life Support',
#   'On The Radio',
#   'I Feel It All',
#   'The Girl',
#   'Baby Came Home 2 / Valentines',
#   'Let It Be Me',
#   'Halcyon',
#   'Medicine',
#   '10,000 Emerald Pools',
#   'Riptide',
#   'Video Games',
#   'Vie En Rose',
#   'Sad Girl',
#   'If I ever feel better',
#   'Old Pine',
#   'All I Want',
#   'Arcadia',
#   'Chasing Cars',
#   "Don't Forget About Me",
#   'All You Ever Wanted',
#   'The Way I Am',
#   'Can You Tell',
#   'Mykonos',
#   'Arabella',
#   'Paint',
#   'The Wilhelm Scream',
#   'Art Deco',
#   'Me',
#   'Sway',
#   'You and I',
#   'Youth',
#   'Summertime Sadness',
#   'Almost Lover',
#   'God Only Knows',
#   'Runaway',
#   'Samson',
#   'Hotel Song',
#   'Leave Your Lover',
#   'Weak',
#   'I And Love And You',
#   'Tee Shirt',
#   'Is There Somebody Who Can Watch You',
#   'Smother',
#   'Fading Through',
#   'From Afar',
#   'Mess Around',
#   'Transatlanticism',
#   'Do I Wanna Know?',
#   'Bridges',
#   'Myth'],
#  ["A Poor Man's Memory",
#   'Into You',
#   'Twuh',
#   'What They Want',
#   'I Fall Apart',
#   'Dreams',
#   'My Life',
#   'Emergency',
#   'Paralyzed',
#   'The Stakeout',
#   'Her (Loving You)',
#   'Gravity',
#   "Don't Leave",
#   'Drive // Stripped',
#   'Act Now',
#   'Let You Down',
#   'Ride Slow',
#   "Let Em' Know",
#   'I Want You So Bad',
#   'Bed Peace',
#   'Letting Go (Dutty Love) featuring Nicki Minaj',
#   'Me You',
#   'I Wanna Go Down With You',
#   'Get Closer - Joe Mason Remix',
#   'The Other',
#   'To Build A Home',
#   'Back To You',
#   'Oxygen',
#   'City Of Stars - From "La La Land" Soundtrack/Pier',
#   'Pull The Trigger',
#   'Not My Type At All',
#   'Get You (feat. Kali Uchis)',
#   'Countdown',
#   "Don't Lie",
#   'No Turning Back',
#   'Summer Air',
#   'Got This',
#   'Sweet Jane',
#   'Family & Friends',
#   'Mercy',
#   'A Thousand Times',
#   'Intro',
#   'Your Hand In Mine',
#   'Cherry Hill',
#   'The Worst',
#   'Jocelyn Flores',
#   'Always Attract',
#   'Blood',
#   'Can You Hold Me',
#   'Flies',
#   'Issues',
#   'Phoenix',
#   'Time Of Our Lives',
#   'Mia & Sebastian’s Theme - From "La La Land" Soundtrack',
#   'Happier',
#   'Losin Control',
#   'MVP',
#   "She Don't (feat. Ty Dolla $Ign)",
#   '10 Feet Down',
#   'Stone',
#   "I'm Here"],
#  ['Sweet Dreams',
#   'You Want More',
#   'Black',
#   'Clean Break',
#   'First',
#   'All Time Low',
#   'Back To The Garden',
#   'Broken-Hearted Girl',
#   'This Town',
#   "You Don't Own Me",
#   'Sun Comes Up',
#   "Like It Doesn't Hurt (feat. Husser)",
#   "Don't Leave Just Yet",
#   'Cocaine Blues',
#   '80s Mercedes',
#   'Miss Atomic Bomb',
#   'Vice',
#   'American Oxygen',
#   'Show Me Love',
#   'In the Dark',
#   'Energy - Main Final',
#   'Saved',
#   'Reasons',
#   'The Way I Love Her',
#   'Weak',
#   'I Wanted You',
#   'Lights Down Low',
#   'Precious',
#   'I Fall Apart',
#   'Torn - Bonus Track',
#   'No Promises',
#   'Scared of Lonely',
#   'Old Guitar',
#   'Your Song',
#   'Bare',
#   "Don't Let Me Get Me - LP Version/Radio Edit",
#   'For Reasons Unknown',
#   'S.O.B.',
#   'Sober',
#   'Letting In',
#   'Your Girl',
#   'High',
#   'Hand In My Pocket - 2015 Remastered',
#   'Bedroom Trip',
#   "For What It's Worth",
#   'No One',
#   'Sinking Deep',
#   'Crash & Burn',
#   'Slow Dance (Acoustic)',
#   'Black Water',
#   'Drifting',
#   'Gravity',
#   'Ahead Of Myself',
#   'Love Me Now',
#   'Dynasty',
#   'watch',
#   'One Dance',
#   'Guys My Age',
#   'Scars To Your Beautiful',
#   'Water Under the Bridge',
#   'Take It All Back 2.0',
#   'Slow Dance',
#   'Oceans Away - Sam Feldt Remix',
#   'Better Man',
#   'I Do',
#   'Same Drugs',
#   'U + Ur Hand',
#   'Knock Knock',
#   'Goodbye',
#   'Your Love',
#   'Everybody Dies In Their Nightmares',
#   'Ruin',
#   "Don't Leave",
#   'Nervous (The Ooh Song) - Mark McCabe Remix',
#   'New',
#   'We Don’t Have To Take Our Clothes Off - The Voice Performance',
#   'Redemption',
#   'I Would Like',
#   'Sweet Jane',
#   'Taking You There',
#   'Next To Me'],
#  ['How Hard I Try',
#   'You Broke Up with Me',
#   'Suntan City',
#   'Cake - East & Young Remix',
#   'Wordplay',
#   'Give Love',
#   'Heartache On The Dance Floor',
#   'Body Like A Back Road',
#   'Malibu',
#   'Upside Down',
#   'My Girl',
#   'Starving',
#   'I Want You Back',
#   'Old Thing Back (feat. Ja Rule and Ralph Tresvant)',
#   'Brown Eyed Girl',
#   'Feels Like Summer',
#   'Springsteen',
#   'Let Me Down Easy',
#   'Love Somebody',
#   'Around The World',
#   'Build Me Up Buttercup',
#   'Island In The Sun',
#   'Beautiful Girl',
#   'Overload',
#   'Santeria',
#   'Daughters',
#   'The Sound Of Sunshine',
#   'Good Girls - Bonus Track',
#   'Steal My Sunshine - Remastered Anniversary Edition',
#   'The Man',
#   'Scar Tissue',
#   'Thotful',
#   'Wonderwall - Remastered',
#   'Thinking Out Loud - Alex Adair Remix',
#   'Slow Hands',
#   'Otherside',
#   'Perfectly Lonely',
#   'Cocoon',
#   'Drift Away',
#   'Only Wanna Be With You',
#   'One Love / People Get Ready',
#   'Follow Me',
#   'Down By The River',
#   'What Do I Know?',
#   'Heaven',
#   'Dive',
#   'Redbone',
#   "Blue Ain't Your Color"],
#  ['PLAGUES',
#   'Of The Night',
#   'Stronger',
#   'Dino War',
#   'On My Way to Heaven - Seven Lions Remix',
#   'All My Friends - 99 Souls Remix',
#   'Stadium - Original Mix',
#   'Promises - Twrk Remix',
#   'Bitches',
#   'What So Not Touched (OWO Vocal Mix)',
#   'To Ü (feat. AlunaGeorge)',
#   'Not Yet',
#   'STONEFIST',
#   'Limelight - NGHTMRE Remix',
#   'Heroes (we could be) - Grandtheft Remix',
#   'Gold Dust - East & Young Remix',
#   "U Don't Know - Slander Remix",
#   'Genghis Khan',
#   'Stranded',
#   'Hiy Hiy (Milkman Remix)',
#   'Hypnotic',
#   'Spaceman - Carnage Festival Trap Remix',
#   'Motley Crew - Gener8ion Remix',
#   'Weekend - Jai Wolf Remix',
#   'Hot As You Want',
#   "Can't Feel My Face - Martin Garrix Remix",
#   "I'll Be Your Reason",
#   'All The Time',
#   'Friends',
#   'Animals - Gryffin Remix',
#   'Rescue Me feat. Juliana Chahayed',
#   'Kill For You',
#   'Beautiful Now - Big Gigantic Remix',
#   'Trndsttr (feat. M. Maggie)',
#   'Slipping Away - Original Mix',
#   'Good For You - Yellow Claw & Cesqeaux Remix',
#   'Cadaverous - Original Mix',
#   'Miracle - Club Mix',
#   'Silhouettes',
#   'Trophy (feat. RahRah The Savage)',
#   'Do You Remember',
#   'Heart Is Full',
#   'Smile - Max Elto Rewind Version',
#   'Things Happen',
#   'Let Me Drive (feat. A.M.I.E. & Mayneday)',
#   'Something Something Champs - Radio Edit',
#   'Xtalk - Kodak to Graph Remix',
#   'Hard to Forget',
#   'Daydreamer - Gryffin Remix',
#   'Own Life (feat. Anderson .Paak)',
#   "Sun Don't Shine",
#   'We are the Hearts',
#   'Want It (feat. Juicy J)',
#   'Dangerous - Oliver Remix',
#   'Summer Time',
#   'Crave You',
#   'Hell Of A Night',
#   'Graffiti',
#   'War',
#   'Idle Hands',
#   'Afterlife (Remix by Frank Pole)',
#   'Your Soul',
#   'One In A Million - Original Mix',
#   'Love You More',
#   'High - US Radio Edit',
#   'Mine - Michael Keenan Remix',
#   'Feel So Close - Nero Remix',
#   'Talking Body - The Young Professionals Remix',
#   'Raindrops - Doorlys Dubstep Remix',
#   'Just A Thought',
#   'Another You - Headhunterz Radio Edit',
#   'Too Much',
#   'Smile',
#   'Rage the Night Away',
#   'Forever Bound (Jorgen Odegard Remix) [feat. Jorgen Odegard]',
#   'Global Concepts',
#   'Body Talk - Radio Edit',
#   'Operate - The Chainsmokers Remix',
#   'Beautiful Now - Marshmello Remix',
#   'Parking Lots (Arpyem Remix)',
#   'Something About You - ODESZA Remix',
#   'Take U Out',
#   'My Song 5',
#   "L'amour toujours - Tiesto Radio Edit",
#   'Capricious (Paces Remix)',
#   'Lost (feat. Marie St. Charles)',
#   "I Don't Like It, I Love It (feat. Robin Thicke & Verdine White) - Kasum Remix"],
#  ["Sweet Child O' Mine",
#   'YYZ',
#   'Shine',
#   'Foreplay / Long Time',
#   'Peace of Mind',
#   'Rock You Like A Hurricane',
#   "He's a Pirate (Pirates of the Caribbean)",
#   'The Blood of Cuchulainn (The Boondock Saints)',
#   'Kashmir',
#   'Tom Sawyer',
#   'Red Barchetta',
#   'Free Bird',
#   'Carry on Wayward Son',
#   'Hold the Line',
#   'U.N. Owen Was Her? (Remix)',
#   'My Shot',
#   'Fortunate Son',
#   'Limelight',
#   'I am the Doctor in Utah',
#   'Right Hand Man',
#   'Stairway To Heaven',
#   'Eye of the Tiger',
#   "Very Bloody Tears (Castlevania II: Simon's Quest)",
#   'Vital Signs',
#   'Crazy',
#   'The Camera Eye',
#   'Sympathy For The Devil',
#   'The Room Where It Happens',
#   'The Majestic Tale (Of A Madman In A Box)',
#   'Pokémon Theme',
#   'Witch Hunt',
#   'Ghost Love Score',
#   'Bohemian Rhapsody - Remastered 2011',
#   'Libera Me From Hell (Tengen Toppa Gurren Lagann)',
#   'Concerning Hobbits (The Lord of the Rings)',
#   'Sweet Home Alabama',
#   'Gimme Shelter',
#   'Alexander Hamilton',
#   'More Than a Feeling'],
#  ['Red Handed',
#   'An Evening with Rthrtha',
#   '84 Pontiac Dream',
#   "Don't Worry.com",
#   'In The Annexe',
#   'Eruption (Gonna Get My Hair Cut at the End of the Summer)',
#   'Slow This Bird Down',
#   'Tears From The Compound Eye',
#   'Satellite Anthem Icarus',
#   'Sixtyten',
#   'Vanishing Lessons',
#   'Biotech',
#   'All the Friends You Can Eat (Original)',
#   'Black Shoes',
#   'Pete Standing Alone',
#   'Spinning Cotton Candy in a Shack Made of Shingles',
#   'An Eagle In Your Mind',
#   'Gyroscope',
#   'Ready Lets Go',
#   'Another Place',
#   'When the Sun Grows on Your Tongue',
#   'Moody Day',
#   'All the Friends You Can Eat',
#   'Falling Off A Horse',
#   'Minka',
#   'Palmistry',
#   'Farewell Fire',
#   'Exploding Snowhorse',
#   'Rue The Whirl',
#   'Old Yes',
#   'Constants Are Changing',
#   'Olson',
#   'A Is To B As B Is To C',
#   'Father Sister Berzerker',
#   'Neon Syrup for the Cemetery Sisters',
#   'Divine Moments of Truth - 2017 Remaster',
#   'Queen',
#   'Shpongle Spores - 2017 Remaster',
#   'Dipsmack',
#   'Twin Of Myself (Original)',
#   'Vapour Rumours',
#   'Oscar See Through Red Eye',
#   'Ghost Moves',
#   'You Could Feel The Sky',
#   'I Saw Drones',
#   'Julie And Candy',
#   'Lipstick Destroyer',
#   'Aquarius',
#   'Upmann',
#   'Melt Me',
#   'Radio Right Now',
#   'Audiomaze',
#   'Street Trash',
#   'Caterpillar House',
#   'Beast Sting',
#   'Chromakey Dreamcoat',
#   'Triangular Objects',
#   'Beware The Friendly Stranger',
#   'Lollpopsichord',
#   'Turquoise Hexagon Sun',
#   'Lost, Picking Flowers in the Woods',
#   'Blow Your Heart',
#   'We Are the Pagans',
#   'Untitled Roadside Demo (Original)',
#   'Devotional',
#   'Truck',
#   'The Smallest Weird Number',
#   'Spitlord',
#   'Mmaj',
#   'Smokes Quantity',
#   'A Moment Of Clarity',
#   'Miss Teardrop',
#   'Ataronchronon',
#   'Good Complexion',
#   'Crooked Breath',
#   'Opening The Mouth',
#   'Streaker (feat. Notrabel)',
#   'I Saw the Bright Shinies',
#   'Kaini Industries',
#   '…And The Day Turned To Night',
#   'Creaming for Beginners',
#   'Magic Window',
#   'Music Is Math',
#   'Big Brother',
#   'Energy Warning',
#   'Forever Heavy',
#   'The Dark Forest Joggers',
#   'Jump into My Mouth and Breathe the Stardust',
#   'Secret Channel',
#   'Telephasic Workshop',
#   'Sleeping Household',
#   'Changing You All',
#   'Behind Closed Eyelids',
#   'Peacock Tail',
#   'The Beach At Redpoint',
#   'One Very Important Thought',
#   'Snow Tip Cap Mountain',
#   'Marilyn Set Me Free',
#   'Sunshine Recorder',
#   'They Live in the Meadow',
#   'What You Gonna Say To Me?',
#   'Spiracle',
#   '1969',
#   'Mockingbird Comes Calling For You',
#   'Copying Soup Onto Sexy Birdy',
#   'Tony Face',
#   'Beds',
#   'Untitled Roadside Demo',
#   'Lollipopsichord',
#   'Face Breakout',
#   'Monster Hit',
#   'Into The Rainbow Vein',
#   'Roygbiv',
#   'Braided Cellophane',
#   'Foxy and the Weight of the World',
#   'Loud Murmuring',
#   'Psychic Swelling',
#   'Video Warning Attempts',
#   'Pool City, McKnight Road',
#   'Sun Lips',
#   'Dayvan Cowboy',
#   'Hey Saturday Sun',
#   'Dandelion',
#   'Untitled Hidden Track',
#   'Marshmallow Window',
#   'The Devil Is In The Details',
#   'Helium Tea',
#   'Omen Classic',
#   'Over The Horizon Radar',
#   'Runite Castles',
#   'Rollerdisco',
#   'Diving Station',
#   'Happy Cycling',
#   'Open The Light',
#   'Self Tanner',
#   'Corsair',
#   'Alla',
#   'Alpha And Omega',
#   'Sherbet Head',
#   'Royal Firecracker Teeth',
#   'Drippy Eye',
#   'Whistling In Tongues',
#   'Dirty Nightgown',
#   'Windshield Smasher',
#   'Bocuma',
#   'Magnetic',
#   'The Touch from Within',
#   'Lemon Lime Face',
#   "Bees Bein' Strugglin'",
#   'Black Blizzard/Red Umbrella',
#   'Wall of Gum',
#   'Triangles & Rhombuses',
#   "It Hurts to Shoot Lazers from Your Fingers, But It's Necessary",
#   'Elq Milq',
#   'Shpongle Falls - 2017 Remaster',
#   'The Afternoon Turns Pink',
#   'The Color Of The Fire',
#   'Wildlife Analysis',
#   'Dawn Chorus',
#   'Happy Melted City'],
#  ['Pretty Girl - Cheat Codes X CADE Remix',
#   'Superficial Love - Single Version',
#   'Symphony (feat. Zara Larsson)',
#   "I'm the One",
#   'Malibu',
#   'If This is Love',
#   'Stay Together',
#   'Despacito - Remix',
#   'Do My Thang',
#   "Help Me Help You (feat. Why Don't We)",
#   'Attention'],
#  ['I Blame You',
#   'Your Hands',
#   'Alone Together',
#   'The Real Her',
#   'Some Other Time',
#   'The Way',
#   'Quick',
#   'Lost & Found',
#   'Fly Before You Fall',
#   'Warm Winds (feat. Isaiah Rashad)',
#   'Jungle',
#   'Tyrone - Live Version',
#   'Shelter',
#   'Honey',
#   'He Loves Me (Lyzel in E Flat)',
#   'Be Ok',
#   'Take Off Your Cool',
#   'Pieces Of Me',
#   'Rolling Hills',
#   'Hello',
#   'Rise Up',
#   'Doing It Wrong',
#   'All I Ever Think About',
#   'Window Seat',
#   'Gone',
#   'Hope She Cheats On You (With A Basketball Player)'],
#  ['Side Of A Bullet',
#   'Rap God',
#   'I Stand Alone',
#   'Next Contestant',
#   'Headstrong',
#   'Seven Nation Army',
#   'Last Resort',
#   'Kryptonite',
#   "'Till I Collapse",
#   'Hell Yeah',
#   'Enter Sandman',
#   'Wild for the Night'],
#  ['Déjà vu',
#   'Fun',
#   'V. 3005',
#   'Hollywood Dreams',
#   '1970',
#   "You're No Good (feat. Santigold, Vybz Kartel, Danielle Haim & Yasmin)",
#   'Magnets',
#   'I Want You',
#   'Love Never Felt so Good - Fedde Le Grand Remix Radio Edit',
#   'No Good For You',
#   'Forever',
#   'R E A L',
#   'Higher',
#   'Uptown Funk',
#   'You Just Want My Money',
#   'Adventure',
#   'Senses (feat. Lostboycrow)',
#   'Ghost',
#   "You're Nobody 'Til Somebody Loves You",
#   'Rockets',
#   'Love Natural',
#   'Hold Me Down',
#   'See You Again (feat. Charlie Puth) - From "Furious 7"',
#   'Do It Again',
#   'To Ü (feat. AlunaGeorge)',
#   'Double Bubble Trouble',
#   'Nobody To Love - Radio Edit',
#   'Golden (feat. Sia)',
#   'For The Town',
#   'Human - Marian Hill Remix',
#   'Peculiar',
#   'Give Me Something',
#   "Like I'm Gonna Lose You",
#   'Mary',
#   'Got It',
#   'By My Side',
#   'Our Own House',
#   'Baby Blue (feat. Chance the Rapper)',
#   'Where Are Ü Now (with Justin Bieber)',
#   'Loud Places',
#   'You Know You Like It',
#   "If It's Not You",
#   'Young Blood',
#   'Lisztomania',
#   'Lost',
#   'Pon De Floor',
#   'Get Down',
#   "You're On",
#   'I Wanna Get Better',
#   'Trumpets',
#   'Love You Crazy',
#   "I Don't Like It, I Love It (feat. Robin Thicke & Verdine White)",
#   'Body Language',
#   'Pity Party',
#   'Psycho',
#   'Milking - Radio Mix',
#   'Five More Hours - Deorro x Chris Brown',
#   'Imagination',
#   'Natalie',
#   'Bend Ova'],
#  ['CAN\'T STOP THE FEELING! (Original Song from DreamWorks Animation\'s "TROLLS")',
#   'Happy - From "Despicable Me 2"',
#   "Like I'm Gonna Lose You",
#   'Fight Song',
#   'Scars To Your Beautiful',
#   'Story of My Life',
#   "Better When I'm Dancin'",
#   'Firework',
#   'Count On Me',
#   'Counting Stars'],
#  ['Islands',
#   'Paper Aeroplane',
#   'Road trip',
#   'VCR',
#   'Never Be Like You - Martin Solveig Remix',
#   'I Like Me Better',
#   'Sunset (Jamie xx Edit)',
#   'You & Me - Flume Remix',
#   "You're Mine - Radio edit",
#   'Intro',
#   'Wicked Games',
#   'Drop the Game',
#   'No One - Kayge Calypso & DUNN Remix',
#   'Angels',
#   'My Boo (feat. Vince Staples, Kučka, Ngaiire & Vera Blue) [Triple J Like A Version]',
#   'Sleepless',
#   'Crystalised',
#   'Young Folks'],
#  ['Untitled 4',
#   'No Guns',
#   'Reprise - T Hemingway Remix',
#   'Zodiac Shit',
#   'Berlin Lovers',
#   'Oe Oe',
#   'Aquarium',
#   'Break Well',
#   "You've Heard",
#   'So Many Times, So Many Ways',
#   'Surrey Ride',
#   'Rains',
#   'Archipelago',
#   'Home Recording',
#   'Killa Cam / Roll That Skit',
#   'With A Professional',
#   'Marriage',
#   'Anchor Steam',
#   'Air (feat. Doom)'],
#  ['Seeing Julie',
#   'She Touched Me',
#   'A Taste Of Honey',
#   'All My Loving',
#   'Feels So Good - Single Version',
#   'Standing Here In Front Of Me',
#   'Gumboots',
#   'Warm Water',
#   'S.A.Y. - Radio Edit',
#   'White Horses',
#   "Ascension (Don't Ever Wonder)",
#   'Spinning Away',
#   'When Dreams Come True (Latin Guitar)',
#   'Santa Fe',
#   'Angel',
#   'Save The Sunlight',
#   'Higher',
#   'This Masquerade',
#   'You Can Close Your Eyes',
#   "Let\\'s Dance",
#   'King and Cross',
#   'Zazueira',
#   'Estrelar',
#   "Don't Wanna Be - Nu Media After Hour Remix Edit",
#   'Afternoon Dreaming',
#   "Draggin' The Line",
#   'Out Of My League',
#   'Walk Between Raindrops',
#   'Betcha By Golly, Wow',
#   'Love Fever',
#   'Matrimony: Maybe You',
#   'Oh, What A Nite',
#   "Let's Do It Together",
#   'Get The Party Started',
#   'Simple Life',
#   'Stories - Remix By F. Gatto',
#   '10,000 Emerald Pools',
#   'Sweet Melody - Original Mix',
#   'Love',
#   "Steppin' Out",
#   'Each Day Gets Better',
#   'Razz Ma Jazz',
#   "Busy Earnin'",
#   'Lullabye',
#   "Didn't I (Blow Your Mind This Time)",
#   'The Luckiest',
#   'Infinita',
#   'Un homme et une femme - Instrumental',
#   'When We Get By',
#   'With This Ring',
#   'Alone in Kyoto',
#   'Harvest Moon',
#   'A Summer Song',
#   'Lose Yourself to Dance',
#   'Shooting Stars',
#   'Vienna',
#   'The Wilhelm Scream',
#   'Outstanding - Original 12" Mix',
#   'Hold On',
#   'High Desert',
#   'Le premier bonheur du jour - Remastered',
#   'Paris (Aeroplane Remix)',
#   'Some Children',
#   'Guitar Twins',
#   'Never My Love - Remastered',
#   "No One's Gonna Love You",
#   'Telephone Line',
#   'Crystal Blue Persuasion - Single Version',
#   'Barcelona Nights',
#   'Comment te dire adieu - It Hurts To Say Goodbye',
#   'Dreaming Siam',
#   'The Air That I Breathe - 2008 Remastered Version',
#   'All I See',
#   'Imagination',
#   'Along Comes Mary',
#   'Our House'],
#  ['Your Eyes (feat. Jay Park)',
#   'Wedding Dress',
#   '전야 前夜 The Eve',
#   'Rose',
#   'BREATHE',
#   '21st Century Girl',
#   'I will go to you like the first snow',
#   'Intro: Serendipity',
#   "You're So Fine",
#   'Untitled, 2014 - KR Ver.',
#   'Take Me',
#   "Don't Recall",
#   'dimple',
#   'Ah-Choo',
#   'Like You',
#   '사실은 The Truth Is',
#   'Ko Ko Bop',
#   'No Make Up',
#   'Call You Bae',
#   'Spring Day',
#   "As If It's Your Last",
#   'Hola Hola',
#   'WHISTLE - KR Ver.',
#   'What U do?',
#   '200%',
#   'DNA',
#   'Hold Me Tight',
#   'NoNoNo',
#   'That Girl (Feat. Loco)',
#   'Inferiority Complex (feat. Eunha)',
#   'FXXK IT',
#   'I Will Show You',
#   "It's Definitely You",
#   '꺼내 먹어요 (Eat)',
#   'Ring My Bell',
#   'Oh NaNa (Hidden. HUR YOUNG JI)',
#   'LAST DANCE',
#   'MIC Drop',
#   'FXXK WIT US',
#   'OUTRO: Divina Commedia - KR Ver.',
#   'Heartstrings',
#   'Yacht (K) [feat. Sik-K]',
#   'GOOD (feat. ELO)',
#   'Roll Deep',
#   'Anck Su Namum',
#   'Ordinary Love',
#   'The Manual',
#   '두근거려 (Beautiful)',
#   'See My Eyes (Heartstring OST)',
#   'Just One Day',
#   'Drive (feat. Gray)',
#   '양화대교 (Yanghwa Brdg)',
#   "Can't Stop",
#   'Solo (feat. Hoody)',
#   'Some (feat.Geeks Lil Boi)',
#   'Dream',
#   'EYES, NOSE, LIPS - KR Ver.',
#   'Me Like Yuh',
#   'Aquaman',
#   'Mr. Chu',
#   'DINOSAUR',
#   'STAY - KR Ver.',
#   'Boys and Girls (feat. Babylon)',
#   'Cliché'],
#  ['Shallow Love',
#   'Tides',
#   'cheatercheaterbestfriendeater',
#   'Like That',
#   'Distance',
#   'Wild Life',
#   'Groove',
#   'Alphabet Boy',
#   'California',
#   'Cold Hearted',
#   'Cheat Codes (feat. Emblem3)',
#   'Doing It Right',
#   'Right Where You Are',
#   'Wrong One',
#   'Flights',
#   'How We Livin',
#   'Paradise (Never Change)'],
#  ['Fat Camp (feat. Kevin Pouya)',
#   'Good Morning',
#   'Hands On The Wheel',
#   'Outlet',
#   'Hollow Be They Squad',
#   'I Wonder',
#   'R.I.P.C.D.',
#   'Litty (feat. Tory Lanez)',
#   'Memo',
#   'Deja Vu',
#   'IT G MA REMIX (feat. A$AP Ferg, Father, Dumbfoundead, Waka Flocka Flame)',
#   'Stronger',
#   'Swimming Pools (Drank)',
#   'XO TOUR Llif3',
#   'Explosive',
#   'Bounce Back',
#   'Shabba',
#   '• Stick & Move',
#   'Stick Talk',
#   'Sacrifices',
#   'Bake Sale (feat. Travis Scott)',
#   'This Is It',
#   'Staring Is Rude',
#   'The Odyssey',
#   'Sick & Tired',
#   'Norf Norf',
#   'Congratulations',
#   'goosebumps',
#   'Real Nigga Hours',
#   'Ginseng Strip 2002',
#   'Blood On The Leaves',
#   'Ghosttown',
#   'Bad Business',
#   'No Role Modelz',
#   'Saint Pablo',
#   'Get Right',
#   'Look Up',
#   'One Night',
#   'No Smoke',
#   "I Don't Like (Remix)",
#   'Revenge',
#   'Free Lunch',
#   'Seppuku (feat. Suicideboy$ & Jgrxxn)',
#   'Kyoto',
#   'Get Got',
#   'Runner',
#   'Catch Me',
#   'I Got the Keys',
#   'Paris - Sam Tiba Remix',
#   "Hell Is You Doin'",
#   'Bank Account',
#   'Good Night',
#   'Hood Pope',
#   'Hennessy & Sailor Moon',
#   'All My Love',
#   'Redbone',
#   'No Heart',
#   'Water',
#   'Everyday We Lit (feat. PnB Rock)',
#   'Wulf Takahashi',
#   'Excuse Yee',
#   'Fire Squad',
#   'Sucker For Pain (with Wiz Khalifa, Imagine Dragons, Logic & Ty Dolla $ign feat. X Ambassadors)',
#   'Story: No Title',
#   'Okay, But This Is the Last Time',
#   '2 Cups Stuffed',
#   'Way Hii',
#   'You Da Baddest',
#   'X (feat. Future)',
#   'Mount Sinai',
#   'Mugen Woe',
#   'Father Stretch My Hands Pt. 1',
#   'Fort Woe',
#   'Heartthrob',
#   "But Wait, There's More (feat. $uicideBoy$)",
#   'ULT',
#   'Put That On My Set',
#   'I Say High and Bye',
#   'LOVE. FEAT. ZACARI.',
#   'Smoking with the Gods',
#   'Black Beatles',
#   'Touchdown',
#   'Material Female',
#   'Leatherface',
#   'Get It Today',
#   'Terrotuga Man',
#   'Young N***a Living',
#   'Mad Men (feat. Xavier Wulf)',
#   'Too Many Years',
#   'My Way',
#   'Terminal Sex',
#   'Bout the Business',
#   'Cashin',
#   'Add It Up (feat. Germ)',
#   'This Life',
#   'Yonkers',
#   'Cold Front',
#   "Poppin' Tags",
#   'Knotty Head',
#   'JoHn Muir',
#   "I'm a Captain Not a Lover",
#   'Bicky Robby (feat. Mikey the Magician & Shakewell)',
#   'Me Now',
#   'Fucked Over',
#   'Everybody in the Club Gettin Shot',
#   'No Flockin',
#   'No One Is Safe',
#   'Jumpman',
#   'Thick (feat. 2 Chainz)',
#   'All over Me',
#   'THat Part',
#   'No Color',
#   '4 AM',
#   'Minnesota',
#   'False Advertisement',
#   'South Side Suicide (feat. Pouya)',
#   'Wulf Wood',
#   'Armor Woe',
#   "I Don't Like",
#   'Facts (Charlie Heat Version)',
#   'Public Announcement',
#   'Skateboard P',
#   'Thunder Man',
#   'Pedals to the Metal (Road Heart)',
#   'Hot N*gga',
#   "Philosopher's Throne",
#   'Paris',
#   'Chin Up',
#   'Half Bae (feat. Pouya)',
#   'Champions',
#   "Hate Bein' Sober",
#   'Wulf of Akina',
#   'Thought It Was a Drought',
#   'Bounce',
#   'FML',
#   'Great Influence',
#   'Crazy Brazy',
#   'A Tale of 2 Citiez',
#   'Head 2 Toe',
#   'Hold My Liquor',
#   'Hyenas',
#   'Really Really',
#   'Ni**as In Paris',
#   'Anthems for a Seventeen Year Old Boy',
#   'F***Umean (feat. Indigochildrick)',
#   'The Cost',
#   'Unforgettable',
#   'Gook',
#   'Wolves',
#   'Kill the Unknown',
#   'Love Sosa',
#   'Real Chill',
#   "Day 'N' Nite (nightmare)",
#   'Sunrise Angel',
#   'Gang',
#   'Yoshi City',
#   'Bag On Me',
#   'Minute',
#   'Pornography',
#   'Worth It',
#   'Magazine',
#   'Switch Man',
#   'Ultimate',
#   'Akina Speed Star',
#   'Kill Yourself, Pt. II',
#   'F*ckwithmeyouknowigotit',
#   'You Know How We Do It',
#   'Voltage',
#   'wokeuplikethis*',
#   'Mankind',
#   'Bouncin',
#   'Gospel',
#   'Waves',
#   'Tortuga',
#   "F**kin' Problems",
#   'Glock In My Benz',
#   'Magnolia',
#   'Timmy Turner',
#   'Look at Me!',
#   'Lockjaw',
#   'Low Life',
#   'Trade-Off',
#   'Dump Dump',
#   'I Want (feat. 2 Chainz)',
#   'Slenderman (feat. Germ)',
#   'When the Lean Runs Out',
#   'Rag & Bone',
#   'White Iverson',
#   'Diary of a Madman - Remastered',
#   'Hard In Da Paint - Explicit Album Version',
#   'Still Cold / Pathway Private',
#   'Leanworld',
#   'Work REMIX',
#   'Money Trees',
#   'T.H.O.T',
#   'Money Man',
#   '1st Summer Night',
#   'Memoirs of a Gorilla',
#   'East Memphis Maniac',
#   'New Level',
#   'Mercy',
#   'Zenith',
#   'Slob on My Knob',
#   "If Tomorrow's Not Here",
#   'Front Man Wulf',
#   'Hunnit Hunnit',
#   'Right Now',
#   'Virginia Tech',
#   'Louis V',
#   'Oak Grove Road',
#   'OG Bobby Johnson',
#   'Politics (feat. Foti)',
#   "I'm the One",
#   'Champion of Death',
#   'Gwinnett',
#   'F*ck Up Some Commas',
#   'Date Night',
#   'Bachelor'],
#  ['Come Hang Out',
#   'Let the Games Begin',
#   'Stay (with Alessia Cara)',
#   'Run For Your Life',
#   'Mirage',
#   'Shape of You - Galantis Remix',
#   'Fenomeno',
#   'Strip That Down',
#   'Despacito - Remix',
#   'Believer',
#   'Something Just Like This',
#   'Cold Shoulder'],
#  ['Mess Is Mine',
#   'Drink You Away',
#   "In Case You Didn't Know",
#   'Let It Go',
#   'Wild Things',
#   'The One That Got Away',
#   'Die A Happy Man',
#   "I'll Be",
#   'My Kind Of Crazy',
#   'Heaven',
#   'Nowhere Fast',
#   'Only Love',
#   'Sure Feels Right',
#   'Wrong Turns',
#   'I See Fire',
#   'Hold Back The River',
#   'Hard To Love',
#   'Like I Loved You'],
#  ['Silhouettes',
#   "Can't Do You (feat. E-40)",
#   'To the Dreamers',
#   'Fix My Eyes',
#   'Hammer Time',
#   'Hallelujah',
#   'O God Forgive Us',
#   'The Proof of Your Love',
#   "It's Not Over Yet",
#   'Your Love Never Fails',
#   'Priceless',
#   'We Believe',
#   'Moving Forward',
#   'Cannot Do This Alone',
#   'Blessings',
#   'All I Need Is You',
#   'No Turning Back',
#   '10,000 Reasons (Bless the Lord) [Radio Version]',
#   'Steady',
#   "God's Not Dead (Like a Lion)",
#   'Run Wild.',
#   'Yes and Amen',
#   'Believer',
#   "I'll Find You",
#   'You Know It'],
#  ['Anything You Can Do',
#   'Popular - From "Wicked" Original Broadway Cast Recording/2003',
#   "I'm Alive",
#   'Masquerade / Why So Silent',
#   'Seize The Day',
#   'Live In Living Color',
#   'Everybody Say Yeah',
#   'The World Will Know',
#   'Lady Marmalade',
#   'Carrying The Banner',
#   'The Schuyler Sisters',
#   'Summer Nights - From "Grease Live!" Music From The Television Event',
#   'Greased Lightnin\' - From "Grease Live!" Music From The Television Event',
#   'Be Our Guest',
#   'Right Hand Man',
#   'Yorktown (The World Turned Upside Down)',
#   'Defying Gravity - From "Wicked" Original Broadway Cast Recording/2003',
#   'Anything Goes',
#   'Dancing Through Life - From "Wicked" Original Broadway Cast Recording/2003',
#   'Another Day Of Sun - From "La La Land" Soundtrack',
#   'Circle Of Life',
#   "Singin' in the Rain",
#   'School Song',
#   "What'd I Miss",
#   'One Day More',
#   "I Just Can't Wait To Be King",
#   'Telly',
#   'Belle',
#   'You\'re The One That I Want - From "Grease Live!" Music From The Television Event',
#   'The Phantom Of The Opera',
#   'Time Warp',
#   'A Musical',
#   'God, I Hate Shakespeare',
#   'Someone In The Crowd - From "La La Land" Soundtrack',
#   'King Of New York',
#   'Alexander Hamilton',
#   'I Got Rhythm',
#   'Do You Hear The People Sing?',
#   'Revolting Children',
#   'Guns and Ships',
#   'We Go Together - From "Grease Live!" Music From The Television Event'],
#  ['3AM',
#   'Headlights',
#   'Asleep - 2011 Remastered Version',
#   'CLEAR',
#   'Growing Up',
#   'Body Like A Back Road',
#   "Superman (It's Not Easy)",
#   'Wing$',
#   'My Girl',
#   'Hallelujah',
#   'Broad Shoulders (feat. Chance the Rapper)',
#   'GREAT NIGHT (feat. Shovels & Rope)',
#   'Rehab',
#   'Mr. Redundant',
#   "It's All Coming Back to Me Now",
#   'Jesus Of Suburbia',
#   'Your Body Is a Wonderland',
#   'Shakedown on 9th Street',
#   'MONEY & FAME',
#   'The Fighter',
#   'TESTIFY',
#   "Big Girls Don't Cry (Personal)",
#   'Devil Like Me',
#   'Closing Time',
#   'WHEN I SING',
#   'MOUNTAIN, Pt 1',
#   'Let It Be - Remastered',
#   'Man in the Mirror - 2012 Remaster',
#   'Countdown',
#   'Final Song',
#   'Gooey',
#   'goosebumps',
#   "All's Well That Ends",
#   "DON'T BRING THAT TROUBLE",
#   'NO EXCUSES',
#   'I Miss You',
#   'BE HERE LONG',
#   'Slow Hands',
#   'Sunday Candy',
#   "This One's for the Girls",
#   'Know Your Enemy',
#   "You'll Think Of Me",
#   'Follow Me',
#   'HARD LOVE',
#   'Everybody Lost Somebody',
#   "Can't Bring This Down",
#   'The Wolves (Act I and II)',
#   'The Comedown',
#   'I Will Always Love You',
#   'HAPPINESS',
#   'Love On The Brain',
#   'Meet Virginia',
#   'Skinny Love',
#   'Sounds Like Hallelujah',
#   'There Will Be Time',
#   'In The Air Tonight - 2015 Remastered',
#   'Candyman',
#   "If I Ain't Got You",
#   "Wouldn't It Be Nice - 2000 - Remaster",
#   'Heaven Go Easy On Me',
#   'Easy (LIke Sunday Morning)',
#   'What Hurts The Most',
#   "LET'S STAY HOME TONIGHT"],
#  ['Into You',
#   'Nights',
#   'Say My Name - Remix Edit',
#   'Know Yourself',
#   'Legend',
#   'Headlights',
#   'Too Good',
#   'Champagne and Pools (feat. Blackbear & Kyle)',
#   'Father Stretch My Hands Pt. 1',
#   'In the Name of Love',
#   'Stronger',
#   'Starving',
#   'Me & My Girls',
#   'Smoke Filled Room - Elephante Remix',
#   'Black Beatles',
#   'Lush Life',
#   'Strange Love',
#   'Intro to Anxiety',
#   'Fame Is for Assholes (feat. Chiddy)',
#   'Energy',
#   'Final Song',
#   'Juju On That Beat (TZ Anthem)',
#   'Close To You',
#   'Bad Things (with Camila Cabello)',
#   'No Role Modelz',
#   'People Keep Talking',
#   'Hello',
#   'Caroline',
#   'Versace (Remix)',
#   'Young, Wild & Free (feat. Bruno Mars) - feat. Bruno Mars',
#   'Bitch Bye!',
#   'You & Me',
#   'Famous',
#   'Fake Love',
#   'Surprise Party (feat. Blackbear)',
#   'I Love Kanye',
#   "Let's Get Lost",
#   'Wet Dreamz',
#   'Same Drugs',
#   'Ivy',
#   'Wasted'],
#  ['Teenage Dream',
#   'Chicken Fried',
#   'Make Me (Cry)',
#   'Boom Boom Pow',
#   'Shape of You',
#   'All Time Low',
#   'Glamorous',
#   'Demons',
#   'In My Head',
#   'Congratulations',
#   'When We Were Young',
#   'I Don’t Wanna Live Forever (Fifty Shades Darker) - From "Fifty Shades Darker (Original Motion Picture Soundtrack)"',
#   'Love On Top',
#   'Tonight Tonight',
#   'Empire State Of Mind',
#   "It's Time",
#   'Love On The Brain',
#   'Losin Control',
#   'Pretty Girls (feat. Travie McCoy)',
#   'Believer',
#   "Blue Ain't Your Color",
#   'Dancing Queen',
#   "Hearts Don't Break Around Here",
#   'Lights Down Low',
#   'Where Them Girls At (feat. Nicki Minaj & Flo Rida) - feat. Nicki Minaj & Flo Rida',
#   'I Write Sins Not Tragedies',
#   "Say You Won't Let Go",
#   'I Got You',
#   'Castle on the Hill',
#   'Imma Be',
#   'How Would You Feel (Paean)',
#   'Sunday Candy',
#   'Radioactive',
#   'What Do I Know?',
#   'One Less Lonely Girl',
#   'Cooler Than Me - Single Mix',
#   'Sweet Home Alabama',
#   'Pon de Replay',
#   'Replay',
#   "Livin' On A Prayer",
#   'What They Want',
#   "Don't Stop Believin'",
#   'Fergalicious',
#   'Sweeter',
#   'September Song',
#   'I Gotta Feeling',
#   'Nancy Mulligan',
#   "That's What I Like",
#   'Bacon',
#   'Supermarket Flowers',
#   'Wonderwall - Remastered',
#   'Dynamite',
#   'Bibia Be Ye Ye',
#   "Burnin' Up",
#   'Best Love Song',
#   'Cinderella',
#   'Beautiful Soul',
#   'Issues',
#   'Dive',
#   'Take It All Back',
#   'Perfect',
#   'Closer',
#   'Barcelona',
#   'Bye Bye Bye',
#   'New Man',
#   'Sweet Caroline',
#   'I Cry',
#   'Chariot',
#   'On Top Of The World',
#   'Trouble',
#   "Club Can't Handle Me (feat. David Guetta) - Feat. David Guetta",
#   'Galway Girl',
#   'I Like It Like That',
#   'Year 3000',
#   'Scared to Be Lonely',
#   'We Are Young (feat. Janelle Monáe) - feat. Janelle Monae',
#   "Big Girls Don't Cry (Personal)",
#   'Save Myself',
#   'Everybody Talks',
#   'Beautiful Girls',
#   'Lot to Learn',
#   'Mercy',
#   'No Scrubs',
#   'All Night (feat. Knox Fortune)',
#   'Stereo Hearts (feat. Adam Levine) - feat. Adam Levine',
#   'Take You There',
#   'Setting the World On Fire',
#   "I'm Gonna Be (500 Miles)",
#   'Happier',
#   'Candyman',
#   'It Girl',
#   'Come On Eileen',
#   'Treat You Better'],
#  ['Wounds',
#   'Turning Japanese',
#   'Interference',
#   'Nostalgic Feel',
#   'Bethlehem',
#   'Eight Miles High',
#   'Strangest Eyes',
#   'Turn It Around',
#   'Lost Youth / Lost You',
#   'Veldt',
#   'Push',
#   'So Much Love So Little Time',
#   'Patroklos',
#   'Deadwater',
#   'Smoking the Day Away',
#   'Vanilla Blue',
#   'Private Life - Edited Version',
#   'Soldiers Requiem',
#   "Nothing's Gonna Hurt You Baby",
#   "What You Won't Do for Love",
#   'Crush The Camera',
#   'Campus',
#   'Sad Valentine',
#   'Affection',
#   'Last Of The Good Old Days',
#   'Weak',
#   'Chemistry',
#   'Wild Sex (In The Working Class) - 1988 Boingo Alive Version',
#   'suncream',
#   'Mess Me Around',
#   'Why iii Love The Moon.',
#   'Big Decisions',
#   "I'm So Ugly",
#   'Contraband',
#   '10:1',
#   'You Loved Me, You Killed Me',
#   'Just Get High',
#   "It's Elizabeth",
#   'Dark as Days',
#   'Fortune Only',
#   'Heart It Races - Dr Dog Version',
#   'Every Moment',
#   'Pink City',
#   'Dræm Girl',
#   'Life Is What You Make It',
#   'Embarrassingly Enough',
#   'Neptune Estate',
#   'CONTACTS',
#   "It's Your Body 4",
#   "I'll Fall",
#   '19',
#   'Screaming',
#   'Cult of Personality',
#   'Serving Goffman',
#   'Luv',
#   "We're Not Just Friends",
#   'Stay (Bedroom Tape)',
#   'El Scorcho',
#   "It's All in Vain",
#   'Looking out for You',
#   'First Balloon To Nice',
#   'End It Now!',
#   'Elegy',
#   'Chief Rocka',
#   'Two Weeks',
#   'Janitor',
#   'HOME',
#   'Strange to Hear',
#   'Rubdown',
#   'Pussy of my Dreams',
#   "She's A Woman [And Now He Is A Man]",
#   'Drugs',
#   'Mistakes',
#   "Can't Come Down",
#   'Danse macabre',
#   'Infinity',
#   'Listen to the Warm',
#   "Love's Been Good To Me",
#   'Poppies',
#   'Crying in Public',
#   'No One Lives Forever',
#   'Trip Switch',
#   "I'll Get Along",
#   'High Plains Anthem',
#   'Sea Song',
#   'Weird Science',
#   'Kalte Wut / Wenn Ich Einmal Reich Bin',
#   'Driftless',
#   'Brazil',
#   "Money Won't Pay",
#   'Lucky Girl',
#   'Piano concerto No. 2 in G Minor, Op. 22: Piano concerto No. 2 in G Minor, Op. 22: II. Allegro scherzando',
#   'Miss You',
#   'I Like You',
#   'Spread A Little Sunshine',
#   "Somebody's Talking",
#   'Touch My Body',
#   "Hey Good Lookin'",
#   'All for Myself',
#   'Crystal',
#   'Camarilla',
#   'Who Got Da Props',
#   'Tried And True',
#   'Drowsy',
#   "You Say I'm in Love",
#   'So Sad, So Sad',
#   "Don't Want To Know If You Are Lonely",
#   'C U Girl',
#   'Necromancer',
#   'i was all over her',
#   'Talk To Me',
#   'A Sunday Kind Of Love - Single Version',
#   'Just Kiss Her',
#   'Endgame',
#   'Signs',
#   'When Did Your Heart Go Missing?',
#   'Under A Rock',
#   'Yet Again',
#   "Bent (Roi's Song)",
#   'Fatalist Palmistry',
#   'Nothing Lasts',
#   "Words I Don't Remember",
#   'Only A Lad',
#   'Sweet Emotion',
#   "Love's Lost Guarantee",
#   'I Love Seattle'],
#  ['Never Be Like You',
#   'All Night',
#   'Serpents',
#   'T-Shirt',
#   'Let It Happen',
#   'You & Me - Flume Remix',
#   'Seaside',
#   'Sexual',
#   'Sun',
#   'It Was Love',
#   'Capsize',
#   'Me & U',
#   'Bounce Back',
#   'All Time Low',
#   'BedRock',
#   'Better Than Me',
#   'I Follow Rivers - The Magician Remix',
#   'I Met This Dude at Coachella (feat. Rykeyz)',
#   'Lay-by',
#   'Dream Car',
#   'Dope on a Rope',
#   'Polymorphing',
#   "I've Given Up on You",
#   'Stay (with Alessia Cara)',
#   'Summertime Sadness [Lana Del Rey vs. Cedric Gervais] - Cedric Gervais Remix',
#   'The Other Side Of Paradise',
#   'Rent Money',
#   'Places To Go',
#   'WYD',
#   'Congratulations',
#   'Naive',
#   'Right Here',
#   'Undercover Martyn',
#   'goosebumps',
#   'Bad Things (with Camila Cabello)',
#   'DARE',
#   'I Wrote This Song For An Ex',
#   'Gay Human Bones',
#   'Your Call',
#   'Everyday',
#   'Too Little, Too Late - Radio Version',
#   'Omen - Radio Edit',
#   'Feels Like We Only Go Backwards',
#   'I Can Talk',
#   'From Time',
#   'Love On The Brain',
#   'New Person, Same Old Mistakes',
#   'Maneater - Remastered',
#   'Losin Control',
#   'Redbone',
#   'Looking Gold',
#   'Feel Good Inc',
# ...
#   'Symphony of the Way: II. On the Threshold of a Bright World',
#   'The Creation (Die Schöpfung) - Text Adjustment: Paul McCreesh / Part 1 / The First Day: Introduction: The Representation Of Chaos',
#   'Rosetta',
#   "Éclairs sur l'Au-Delà: 2. La Constellation du Sagittaire",
#   "Where We're Going",
#   'One Earth, One People, One Love (from Sun Rings)',
#   'Keep Talking',
#   'Aiôn, quattro episodi di una giornata di Brahama: I',
#   'Ceres',
#   'An der schönen blauen Donau, Op.314',
#   'Spaces in Time',
#   'Main Title and The Attack on the Jakku Village',
#   'Bluebird - K-Pax (Original Motion Picture Soundtrack)',
#   'Das Rheingold: Prelude',
#   "Gayane Suite No. 3: IV. Gayane's Adagio",
#   'Lament For Atlantis',
#   'Remote Galaxy Op.81',
#   'Sunshine (Adagio in D Minor)',
#   'Symphony No. 48, Op. 355 "Vision of Andromeda": II. Fugue: Allegro',
#   "Time's Arrow: The void - Explosive exposition (excerpt)",
#   'Andromede',
#   'The Departure',
#   'Blue Curve of the Earth',
#   'Three Million Light Years From Home - From "E.T. The Extra-Terrestrial" Soundtrack',
#   'Celestial Mechanics - Makrokosmos IV: I. Alpha Centauri',
#   'Symphony No. 53, Op. 378, "Star Dawn": II. Moderato sostenuto con molta espressione',
#   'Zodiacs',
#   '"All That Is or Ever Was or Ever Will Be"',
#   "Theme From The TV Series 'Cosmos' - Heaven And Hell, 3rd Movement",
#   'The Light 3000'],
#  ['Hella Hoes',
#   "Don't",
#   'Take It Back',
#   'Both Eyes Closed (feat. 2 Chainz and Young Dolph)',
#   'How Do U Feel (Remix)',
#   "I'm A Nasty Hoe",
#   'Skateboard P',
#   'Dani California',
#   'Ink Blot',
#   'Mr. Tokyo',
#   'Take Your Place',
#   'wokeuplikethis*',
#   'Fie Bars',
#   'HUMBLE.',
#   'Big Rings',
#   '15th And The 1st (feat. YG Hootie)',
#   'Ex Calling',
#   'IT G MA REMIX (feat. A$AP Ferg, Father, Dumbfoundead, Waka Flocka Flame)',
#   '1000 Rounds',
#   'L.Y.B.B. (Resolution)',
#   'Multiply',
#   'Life Is Short',
#   'Converting...',
#   'Magnolia',
#   'Paris',
#   'Butterfly Effect',
#   'Mary Jane',
#   'Shoot the 3',
#   'Slave Ship (feat. Waka Flocka Flame)',
#   'Free Smoke',
#   'Smartphone',
#   'Audi.',
#   'I Want (feat. 2 Chainz)',
#   'Smoking with the Gods',
#   'Yamborghini High',
#   'Both (feat. Drake)',
#   'Stop Smoking Black & Milds',
#   'XO TOUR Llif3',
#   'Gucci Polo',
#   "All That Glitters Is Not Gold, but It's Still Damn Beautiful",
#   'Like A Maverick',
#   'Welcome To The Booty Tape',
#   'Fuck Ugly God',
#   'Add It Up (feat. Germ)',
#   'Like A Soccer Mom',
#   'Dance With The Devil',
#   'London Town',
#   '2 Hot 4 U (feat. $Uicdeboy$)',
#   'RAF',
#   'Memoirs of a Gorilla',
#   'Perplexing Pegasus',
#   'It Was A Good Day',
#   'Choices (Yup)',
#   'I Get The Bag (feat. Migos)',
#   'Enemies',
#   'FYBR (First Year Being Rich)',
#   'Telephone Calls',
#   'Slob on My Knob',
#   'Threatz',
#   'Cherry Hill',
#   'No Complaints',
#   'Runner',
#   'Front & Center',
#   'Freak',
#   'Bank Account',
#   'Portland',
#   '4 AM',
#   'DJ Khaled',
#   'Renewed',
#   'Hop Out',
#   'South Side Suicide (feat. Pouya)',
#   'Ultimate',
#   'Redbone',
#   'Look At Me!'],
#  ['Laisse tomber les filles',
#   'Teenage Dream',
#   'The Last Race (Death Proof)',
#   'Across 110th Street',
#   'You Never Can Tell',
#   'Son Of A Preacher Man - Mono Version',
#   'Chez les yéyé',
#   'Lola',
#   'Rumble',
#   "She's A Burglar",
#   'Hold Tight!',
#   'Mambo Sun - Remastered',
#   'Theme for the Lime Cafe',
#   'My Thang',
#   'All I Wanna Do',
#   "Baby It's You",
#   'I Heard It Through The Grapevine',
#   'Out Of Limits',
#   'Down In Mexico',
#   'The Vulture',
#   'Pass The Peas',
#   'Midnight Train to Georgia - Single Version',
#   'Bang Bang (My Baby Shot Me Down)',
#   'I Got The... - 2006 Remastered Version',
#   'Funky Fanfare',
#   "Let's Stay Together",
#   'Warm And Tender Love',
#   '18 With A Bullet',
#   'The Passenger',
#   'Surf Rider',
#   'Strawberry Letter 23 (Re-recorded / Remastered)',
#   'Jungle Boogie',
#   'Jeepster - Remastered',
#   'Since I First Met You',
#   "Bustin' Surfboards",
#   'Crystal Tokyo Jazz',
#   'Street Life',
#   'Cocaine',
#   'Staggolee',
#   'Gloria - Stereo Version',
#   'The Love You Save (May Be Your Own)',
#   "I'm A Midnight Mover"],
#  ['Black Betty',
#   'Shout It Out Loud',
#   'The Final Countdown',
#   'Steve Jobs vs Bill Gates',
#   "We Didn't Start the Fire",
#   'Ring of Fire - Mono Version',
#   'I Can Only Imagine',
#   'Die Walkure, Act III: Ride of the Valkyries',
#   'Moves Like Jagger - Studio Recording From The Voice Performance',
#   'Barbie Girl',
#   'American Pie',
#   "Don't Stop Believin'",
#   'America Fuck Yeah (Originally Performed By Team America) [Tribute Version]',
#   'American Ride',
#   "U Can't Touch This",
#   'Detroit Rock City',
#   'The Ultimate Showdown of Ultimate Destiny',
#   'The Lion Sleeps Tonight',
#   'Song of the South',
#   'Who Let The Dogs Out',
#   "I've Been Everywhere",
#   'We Are Young (feat. Janelle Monáe) - feat. Janelle Monae',
#   'William Tell Overture',
#   "Safety Dance - From the TV Serie ''Scrubs''",
#   'White & Nerdy (Parody of "Ridin\'" by Chamillionaire feat. Krayzie Bone)',
#   'Mozart vs Skrillex',
#   'The Fox (YouTube Version)',
#   'Your Man',
#   'State Of My Head',
#   'Magic Dance (Single Version) - 2002 Remastered Version',
#   'Another Brick in the Wall, Pt. 2',
#   'Amish Paradise (Parody of "Gangsta\'s Paradise" by Coolio)',
#   'Jump On It',
#   'The Devil Went Down to Georgia',
#   'Play That Funky Music',
#   'Rock Me Amadeus - The Gold Mix',
#   'Live And Let Die',
#   'Wrecking Ball',
#   'Blue (Da Ba Dee) - Video Edit',
#   'Dragostea Din Tei - Original Italian Version',
#   'War',
#   'Gangnam Style (강남스타일)',
#   'Radioactive',
#   'The Sound Of Silence',
#   'Yoda',
#   'Savior',
#   'Ice Ice Baby',
#   'Birdhouse In Your Soul',
#   'Courtesy Of The Red, White And Blue (The Angry American)',
#   'Three Wooden Crosses',
#   'Shout',
#   'The Impossible',
#   'Cotton Eye Joe',
#   'Rock And Roll All Nite',
#   "Don't Take The Girl",
#   'Du hast'],
#  ['What They Want',
#   'Skateboard P',
#   'Baker Street',
#   'Bad and Boujee (feat. Lil Uzi Vert)',
#   'Deja Vu',
#   'March Madness',
#   'There He Go',
#   'The Sweet Escape',
#   'One Reason (Flex) [feat. Eric Bellinger]',
#   'Ran Off On Da Plug Twice',
#   'Both (feat. Drake)',
#   'Too Many Years',
#   'Tunnel Vision',
#   'No Problem (feat. Lil Wayne & 2 Chainz)',
#   'Congratulations',
#   'Ps & Qs',
#   'Too Much Sauce',
#   'Whatever You Like',
#   'New Level',
#   'Immortal',
#   "Don't Wanna Know (feat. Kendrick Lamar)",
#   'iSpy (feat. Lil Yachty)',
#   'Gassed Up',
#   'Erase Your Social',
#   'Planez',
#   'Swang',
#   'You Was Right'],
#  ['Worthy',
#   "Don't",
#   'Mad Solar',
#   'Unfold',
#   'Lady In A Glass Dress (Interlude)',
#   'With You',
#   'What You Need',
#   'Next',
#   'The Hills',
#   'Promise',
#   'In The Night',
#   'Consideration',
#   'Pills N Potions',
#   'Jungle',
#   'Shoulda Been There (feat. B.o.B)',
#   'Finessin',
#   "Grass Ain't Greener",
#   'Come Thru',
#   'Coming Down',
#   'Recognize (feat. Drake)',
#   'Caretaker (feat. SZA)',
#   'Feel No Ways',
#   'Autumn Leaves',
#   'Acquainted',
#   'Lights Out',
#   'Break From Toronto',
#   'Remember Me',
#   'Shameless',
#   'Comfortable',
#   'Needed Me',
#   'Back To Sleep',
#   'ABRACADABRA. - Reloaded MIXTAPE',
#   'Our Love',
#   'Work',
#   'Exchange',
#   'Been That Way',
#   'No Time For It',
#   'I’m Yours',
#   'Mine',
#   'The Fix (feat. Jeremih)',
#   'Stay - Album Version (Edited)',
#   'Rolling Stone',
#   'Father Stretch My Hands Pt. 1',
#   'Wicked Games',
#   'Mine Games',
#   'Mirrors',
#   "Can't Feel My Face",
#   'Remember My Name',
#   'Come and See Me (feat. Drake)',
#   'Do Not Disturb',
#   'Shut It Down',
#   'Prisoner',
#   'oui',
#   'Often',
#   'LA Confidential',
#   'SEARCHIN - Reloaded MIXTAPE',
#   'Holy Grail',
#   'Sober',
#   'The Morning',
#   'Take Care',
#   'Simple Things (Remix)',
#   'All My Friends',
#   'Saved (feat. E-40)',
#   'Again',
#   'Furthest Thing',
#   'As You Are',
#   'TBH',
#   'Want Some (feat. DJ Chose)',
#   'Drunk Texting',
#   'Liquor',
#   'Part II (On The Run)',
#   'I Just Wanna...',
#   'You And Your Friends (feat. Snoop Dogg & Ty Dolla $ign)',
#   'The Real Her',
#   "I'm From Long Beach",
#   'Tuscan Leather',
#   'Coffee (F***ing)',
#   'Real Life',
#   'Angel',
#   'Changes',
#   'Make It Home',
#   'Cameras / Good Ones Go Interlude - Medley',
#   "Hold On, We're Going Home",
#   'With Me',
#   'Her Way',
#   'Tonite',
#   'Unforgettable',
#   'Wednesday Night Interlude',
#   'Slow Motion',
#   'Forever (feat. Santigold & 1st)',
#   "It Won't Stop (feat. Chris Brown)",
#   'Earned It (Fifty Shades Of Grey)',
#   'Doing It Wrong',
#   'Planez',
#   'Gone',
#   "You Don't Know (feat. Wale)",
#   'Tell Your Friends',
#   'Time (feat. Monty)',
#   'Party Favors',
#   'The Knowing',
#   'Own It',
#   'Karaoke',
#   'WTH',
#   '2AM.',
#   'I Love Ya (feat. Yo Gotti)',
#   'White Iverson',
#   'Too Much',
#   'Party Hard / Cadillac (Interlude)',
#   "Who's Gonna (NOBODY)",
#   'Say It',
#   'New Flame',
#   'PILLOWTALK',
#   'The Party & The After Party',
#   'Make Up',
#   'High For This',
#   'Collide (feat. Tyga)',
#   "Runnin' (Lose It All)",
#   '7 Years',
#   'Better',
#   'Dark Times',
#   "Don't Mind",
#   'Impatient',
#   'Sorry',
#   'Loveeeeeee Song',
#   'Yeah, I Said It'],
#  ['Sippin’ On Fire',
#   'Night Train',
#   'Tip It Back',
#   'The One That Got Away',
#   'Sure Be Cool If You Did',
#   'This Is How We Roll',
#   'Tell Me How You Like It',
#   'Round Here',
#   'Up All Night',
#   'When the Sun Goes Down',
#   'Somewhere In My Car',
#   'Your Man',
#   'Check Yes Or No',
#   'Die A Happy Man',
#   'We Are Tonight',
#   'Carolina',
#   'Dirt',
#   'Get Your Shine On',
#   'No Shoes, No Shirt, No Problems - Re-Tracked / Master Version',
#   'How Country Feels',
#   'She Cranks My Tractor',
#   'All Over The Road',
#   'I Like It, I Love It',
#   'The General',
#   'Honky Tonk Badonkadonk',
#   'Mine Would Be You',
#   'Take You Home',
#   'Little Bit Of Everything',
#   'My Eyes - feat. Gwen Sebastian',
#   'Drink In My Hand',
#   'I Like You a Lot',
#   "It's Five O' Clock Somewhere",
#   'Lose My Mind',
#   'Bottoms Up',
#   'Talladega',
#   "Don't Ya",
#   "Meanwhile Back At Mama's",
#   "Hell Raisin' Heat Of The Summer",
#   '5-1-5-0',
#   'Dayum, Baby',
#   'Southern Comfort Zone',
#   'Beat Of The Music',
#   'Summertime',
#   'John Cougar, John Deere, John 3:16',
#   'Happens All The Time',
#   'Party People',
#   'Anywhere With You',
#   'Honey Bee',
#   'Something Like That',
#   "Whatever She's Got",
#   'Cop Car',
#   "Don't It",
#   'It Goes Like This',
#   'Tonight Looks Good on You',
#   'Shotgun Rider',
#   'Leave The Night On',
#   "Crushin' It",
#   'Hell Of A Night',
#   'Yeah',
#   "That's My Kind Of Night",
#   'Somebody Like You',
#   'People Are Crazy',
#   'Cruise',
#   'Save A Horse (Ride A Cowboy)',
#   'Crash And Burn',
#   'Mexico, Tequila And Me',
#   'Sun Daze',
#   'Barefoot Blue Jean Night',
#   'Get Me Some Of That',
#   'Cowboys and Angels',
#   'Break Up In A Small Town',
#   'Make Me Wanna',
#   "Runnin' Outta Moonlight",
#   'Sunny and 75',
#   'Dirt Road Anthem',
#   "It'z Just What We Do",
#   "Missin' You Crazy",
#   'Smoke',
#   'Banjo',
#   'Hey Girl',
#   'Springsteen',
#   'Beer In Mexico',
#   'Diamond Rings And Old Barstools',
#   'Where The Green Grass Grows',
#   'God Gave Me You',
#   "Where It's At",
#   'Stay',
#   "Here's To The Good Times",
#   "Good At Startin' Fires",
#   'Confession',
#   'River Bank',
#   "Boys 'Round Here (feat. Pistol Annies & Friends)",
#   'Good Directions',
#   'Drunk On A Plane',
#   'Lonely Eyes',
#   "Beachin'",
#   'Close Your Eyes',
#   "Doin' What She Likes",
#   'Aw Naw'],
#  ['The Chain',
#   'I Love You',
#   'Upside Down',
#   'New Soul',
#   'Royals',
#   'Patience, Please',
#   'Let Her Go',
#   'The Call',
#   'Valerie - Live At BBC Radio 1 Live Lounge, London / 2007',
#   'Bennie And The Jets - American Idol Performance',
#   'Island In The Sun',
#   "Let's Groove",
#   'PILLOWTALK',
#   'My New Philosophy',
#   'Put Your Records On',
#   "Like I'm Gonna Lose You",
#   'Brothers',
#   'Somewhere Only We Know',
#   'Budapest',
#   "I'd Rather Be With You [Radio Edit]",
#   'Better Together',
#   'Bed Down',
#   'Collide - Acoustic Version',
#   'Wrecking Ball',
#   'Somebody That I Used to Know',
#   'Big Yellow Taxi',
#   'Run to You',
#   'Titanium',
#   'I Wanna Fall In Love',
#   'Badge And Gun',
#   'Lucky',
#   'Almost Everything',
#   'Fidelity',
#   'Wake Me up Before You Go-Go',
#   "I Think I'm In Love",
#   'Dream A Little Dream Of Me - Album Version With Introduction',
#   'Ho Hey',
#   'Something That I Want',
#   'Closer',
#   'Hold My Breath'],
#  ['Not Too Fast',
#   "I Don't Wanna Wait",
#   'Buffalo Soldier',
#   "Howlin' For You",
#   'Let Me Know',
#   'Lay Me Down',
#   'Rest of My Life',
#   'Voices',
#   'Blind To You - Explicit Album Version',
#   'Welcome To Jamrock',
#   'Three Little Birds',
#   'Let Me Be',
#   'California Girl',
#   'Above My Floor',
#   'Roses',
#   'Sitting, Waiting, Wishing',
#   "You'll Think Of Me - Live",
#   'T.G.I.F.',
#   "What It's Like",
#   'Catalina',
#   'Runaway',
#   'There For You',
#   'What I Got',
#   "Now That It's Over",
#   'Wiseman',
#   'Rasta Love Feat. Ky-Mani Marley',
#   'Sweet Southern Moon',
#   'Gimmie Love',
#   'Close My Eyes',
#   'Safe And Sound',
#   'Summertime Baby',
#   'Gone Going',
#   'You and Me',
#   'Falling',
#   'When the Feeling Goes Away',
#   'Little Black Dress',
#   'Time Bomb',
#   'Mudfootball',
#   'Girl Next Door',
#   'Come Around',
#   'Wait And See',
#   'Caress Me Down',
#   'World A Music',
#   'Feeling Alright',
#   'Wish You Were Here',
#   'And I Dream',
#   'Summer Nights',
#   'True Love',
#   'Beautiful',
#   'Santeria',
#   'Ordinary Girl',
#   'I Survive',
#   'Corona And Lime',
#   'Shadow - feat. Trevor Young',
#   'Closer I Get (feat. John Popper)',
#   'Up Up & Away',
#   'Idea Of Happiness - Original',
#   'Mellow Mood',
#   'Scoreboard',
#   'Right Me Up',
#   'No Woman, No Cry - Live At The Lyceum, London/1975',
#   'Collie Man',
#   'Fly Away (feat. Collie Buddz)',
#   'In the Summertime - feat. Rayvon',
#   'Badfish',
#   'Here I Am',
#   'Sky Is the Limit',
#   'Watch it Burn',
#   'Road To Zion',
#   'What A Feeling',
#   'Turn Around',
#   "Can't Keep Me Down",
#   'Ganja Baby',
#   'The Girls (feat. Weege)',
#   'Wrong Way',
#   'New Heights',
#   "Pimpa's Paradise",
#   'The Drugs',
#   'Wild Wild Horses',
#   "Buzzin'",
#   'Better Together',
#   'Yesterday',
#   'Courage To Grow',
#   'Follow Me',
#   'My Sweet Summer',
#   'Take Control',
#   'Nice & Slow',
#   'Officer',
#   'Smoke Marijuana'],
#  ['In the Kitchen',
#   'On Time (feat. TuPhace)',
#   'Portal to an Empty Head',
#   'This Must Be the Place (Naive Melody)',
#   'Sirens',
#   'Teakwood Betz',
#   'Tweezer Reprise - Live'],
#  ["Highway Don't Care",
#   'What Kinda Gone',
#   'Song for Another Time',
#   'Just to See You Smile',
#   'For Her',
#   'Noise',
#   'Helluva Life',
#   'Body Like A Back Road',
#   'Hey Pretty Girl',
#   'Let Me See Ya Girl',
#   'Colder Weather',
#   "She's Got a Way With Words",
#   "That's When You Know It's Over",
#   'Who I Am With You',
#   'How Not To',
#   'My Girl',
#   'Move',
#   'Riser',
#   'Yours',
#   'A Woman Like You',
#   'Break Up with Him',
#   'Like You Ain’t Even Gone',
#   'Somebody Else Will',
#   'Whiskey Lullaby',
#   'The Fighter',
#   'Show You Off',
#   'Island',
#   'Goodbye In Her Eyes',
#   'Tomorrow',
#   'Rain Is a Good Thing',
#   "Lovin' Lately",
#   'Make You Miss Me',
#   'Drunk Last Night',
#   'Star Of The Show',
#   'Beautiful Drug',
#   'Felt Good On My Lips',
#   'Sleep Without You',
#   'It All Started with a Beer',
#   "I'm In A Hurry (And Don't Know Why)",
#   "In Case You Didn't Know",
#   'Even If It Breaks Your Heart',
#   'Wanna Be That Song',
#   "You Ain't Here To Kiss Me",
#   'One Hell Of An Amen',
#   'Crazy Girl',
#   'The Thunder Rolls',
#   'Better Man',
#   'Drink A Beer',
#   'Every Storm (Runs Out Of Rain)',
#   'Think of You',
#   "You're Gonna Miss This",
#   'Redneck Crazy',
#   "Nothin' Like You",
#   'Middle of a Memory',
#   'Roller Coaster',
#   'Every Time I Hear That Song',
#   'If I Told You',
#   'I Run to You',
#   'Remember When',
#   'Take Your Time',
#   'Sunshine & Whiskey',
#   "That don't sound like You",
#   'Blue Tacoma',
#   'Make You Mine',
#   'Setting the World On Fire',
#   'Running For You',
#   'What You Do To Me',
#   'Where It All Begins (feat. Lady Antebellum)',
#   'We Were Us',
#   'Love You Like That'],
#  ['El Tao Tao',
#   'Juana La Cubana',
#   'Party In Miami',
#   'Amor De Pobre - No Tengo Dinero (Hip-Hop Version)',
#   'El Regeton',
#   'La Mesa Que Mas Aplauda (Za Za Za)',
#   'El Mario de Tu Mujer (feat. Don Miguelo)',
#   'El Hombre Es Como El Oso',
#   'Tu Pun Pun',
#   'La Vaca',
#   'Que Lo Que',
#   'Muévelo',
#   'La Bomba',
#   'A Quién Le Importa',
#   'Un Ladrón'],
#  ...]

# %% [markdown]
# # Algoritmo Apriori

# %% [markdown]
# ## Funcion para crear el primer nivel, recorriendo todas las canciones

# %%
def primerNivel(datos,min):
    listaCancionesTodas = {} 
    listaAparicion={}
    newMin=min*len(datos)
    for playlist in datos:
      for grupoCanciones in playlist:
        listaCancionesTodas[grupoCanciones] = listaCancionesTodas.get(grupoCanciones, 0) + 1
        listaAparicion[grupoCanciones]=listaAparicion.get(grupoCanciones, [])+[datos.index(playlist)]
    listaCancionesPasan=[]
    listaAparicionPasan={}
    for dato in listaAparicion:
      if(len(listaAparicion[dato])>=newMin):
        listaCancionesPasan.append([dato])
        listaAparicionPasan[tuple([dato])]=listaAparicion.get(dato)
    lista1=sorted(listaAparicionPasan.items())
    return lista1

# %% [markdown]
# ## Funcion usada para la creacion de un nuevo nivel a partir del anterior

# %%
def crearNivel(datosPrevios,tamañoDatos,min,nivel):
  nuevoNivel={}
  numDatosPrevios=len(datosPrevios)
  newMin=min*tamañoDatos
  listaAparicion={}
  for i in range(numDatosPrevios):
    for j in range(i+1,numDatosPrevios):
      L1 = datosPrevios[i][0] [: nivel]
      L2 = datosPrevios[j][0] [: nivel] 
      L11=sorted(L1)
      L22=sorted(L2)
      if L11==L22:
        nuevoElemento=set(datosPrevios [i][0]) | set(datosPrevios [j][0])
        subconjunto=list(combinations(list(nuevoElemento),nivel+1))
        conjuntoAparicion=set(datosPrevios[i][1])&set(datosPrevios[j][1])
        nuevoNivel[tuple(nuevoElemento)]=list(conjuntoAparicion)
  listaPasan={}
  for key in nuevoNivel:
    if(len(nuevoNivel[key])>=newMin):
      listaPasan[key]=nuevoNivel.get(key)
  
  lista1=sorted(listaPasan.items())
  return lista1

# %% [markdown]
# ## Creacion de los Itemsets con Apriori

# %%
def apriori(datos,suport):
    inicio = primerNivel(datos,suport)
    tamañoDatos=len(datos)
    ListaItemsets = [inicio]
    k = 0
    indicador=True
    while (indicador):
        nivelK = crearNivel(ListaItemsets[k],tamañoDatos, suport,k)
        if(len(nivelK)>0):
            ListaItemsets.append(nivelK)
        else:
            indicador=False
        k += 1

    #for i in range(len(ListaItemsets))
    return ListaItemsets

# %% [markdown]
# ### Encontramos los itemsets frecuentes

# %%
itemsets=apriori(playlists,0.015)

# %% [markdown]
# ### Mostramos los itemsets encontrados y cuantos niveles tiene

# %%
for i in range( len(itemsets)):
    print("- Elementos del nivel",i+1,"son ",len(itemsets[i]))
# Out:
# - Elementos del nivel 1 son  349
# - Elementos del nivel 2 son  22

# %% [markdown]
# ### Mostramos el soporte de los elementos

# %%
for i in range(len(itemsets)):
    print("========== Itemsets de ",i+1,"elementos ==========")
    for elemento in itemsets[i]:
        print("-",elemento[0],"tienen un soporte de: ",len(elemento[1])/len(playlists))
# Out:
# ========== Itemsets de  1 elementos ==========
# - ("'Till I Collapse",) tienen un soporte de:  0.0169
# - ('0 To 100 / The Catch Up',) tienen un soporte de:  0.0161
# - ('1-800-273-8255',) tienen un soporte de:  0.0264
# - ('24K Magic',) tienen un soporte de:  0.0167
# - ('679 (feat. Remy Boyz)',) tienen un soporte de:  0.0244
# - ('7 Years',) tienen un soporte de:  0.0188
# - ('7/11',) tienen un soporte de:  0.015
# - ('Africa',) tienen un soporte de:  0.0168
# - ('Again',) tienen un soporte de:  0.0212
# - ("Ain't No Mountain High Enough",) tienen un soporte de:  0.0222
# - ('Alive',) tienen un soporte de:  0.0224
# - ('All I Want',) tienen un soporte de:  0.0221
# - ('All My Friends',) tienen un soporte de:  0.0186
# - ('All Night',) tienen un soporte de:  0.0153
# - ('All Night (feat. Knox Fortune)',) tienen un soporte de:  0.0166
# - ('All Star',) tienen un soporte de:  0.0166
# - ('All The Small Things',) tienen un soporte de:  0.0165
# - ('All Time Low',) tienen un soporte de:  0.0189
# - ('All of Me',) tienen un soporte de:  0.0235
# - ('Alone',) tienen un soporte de:  0.0206
# - ('Alright',) tienen un soporte de:  0.0263
# - ('Angel',) tienen un soporte de:  0.0218
# - ('Antidote',) tienen un soporte de:  0.026
# - ('Attention',) tienen un soporte de:  0.0153
# - ('Back To Back',) tienen un soporte de:  0.0167
# - ('Bad and Boujee (feat. Lil Uzi Vert)',) tienen un soporte de:  0.0345
# - ('Bang Bang',) tienen un soporte de:  0.018
# - ('Bank Account',) tienen un soporte de:  0.023
# - ('Beautiful',) tienen un soporte de:  0.019
# - ('Beautiful Girls',) tienen un soporte de:  0.0151
# - ('Believe',) tienen un soporte de:  0.0211
# - ('Believer',) tienen un soporte de:  0.0246
# - ('Best I Ever Had',) tienen un soporte de:  0.0154
# - ('Better Together',) tienen un soporte de:  0.0152
# - ('Billie Jean',) tienen un soporte de:  0.0189
# - ('Black Beatles',) tienen un soporte de:  0.0285
# - ('Blessings',) tienen un soporte de:  0.026
# - ('Bodak Yellow',) tienen un soporte de:  0.0187
# - ('Body Like A Back Road',) tienen un soporte de:  0.0267
# - ('Bohemian Rhapsody - Remastered 2011',) tienen un soporte de:  0.024
# - ('Bonfire',) tienen un soporte de:  0.0176
# - ('Bounce Back',) tienen un soporte de:  0.0297
# - ('Breathe',) tienen un soporte de:  0.0151
# - ('Breezeblocks',) tienen un soporte de:  0.0164
# - ('Broccoli (feat. Lil Yachty)',) tienen un soporte de:  0.0399
# - ('Brown Eyed Girl',) tienen un soporte de:  0.0185
# - ('Budapest',) tienen un soporte de:  0.0164
# - ('Butterfly Effect',) tienen un soporte de:  0.0194
# - ("Buy U a Drank (Shawty Snappin')",) tienen un soporte de:  0.0167
# - ('CAN\'T STOP THE FEELING! (Original Song from DreamWorks Animation\'s "TROLLS")',) tienen un soporte de:  0.0205
# - ('Cake By The Ocean',) tienen un soporte de:  0.0165
# - ('California',) tienen un soporte de:  0.0151
# - ("Can't Feel My Face",) tienen un soporte de:  0.0222
# - ("Can't Help Falling in Love",) tienen un soporte de:  0.0156
# - ("Can't Hold Us - feat. Ray Dalton",) tienen un soporte de:  0.0183
# - ('Caroline',) tienen un soporte de:  0.039
# - ('Chandelier',) tienen un soporte de:  0.0161
# - ('Chasing Cars',) tienen un soporte de:  0.0183
# - ('Cheap Thrills',) tienen un soporte de:  0.0209
# - ('Cheerleader - Felix Jaehn Remix Radio Edit',) tienen un soporte de:  0.0182
# - ('Chicken Fried',) tienen un soporte de:  0.0214
# - ('Chill Bill',) tienen un soporte de:  0.0228
# - ('Closer',) tienen un soporte de:  0.0723
# - ('Cold Water (feat. Justin Bieber & MØ)',) tienen un soporte de:  0.0234
# - ('Come Get Her',) tienen un soporte de:  0.0172
# - ('Come On Eileen',) tienen un soporte de:  0.0204
# - ('Come and See Me (feat. Drake)',) tienen un soporte de:  0.015
# - ('Congratulations',) tienen un soporte de:  0.0403
# - ('Controlla',) tienen un soporte de:  0.0206
# - ('Counting Stars',) tienen un soporte de:  0.0171
# - ('Crazy',) tienen un soporte de:  0.0208
# - ('Crazy In Love',) tienen un soporte de:  0.019
# - ('Creep',) tienen un soporte de:  0.0153
# - ('Cruise',) tienen un soporte de:  0.017
# - ('DNA.',) tienen un soporte de:  0.0231
# - ('Deja Vu',) tienen un soporte de:  0.0245
# - ('Demons',) tienen un soporte de:  0.0191
# - ('Despacito - Remix',) tienen un soporte de:  0.0282
# - ('Die A Happy Man',) tienen un soporte de:  0.0209
# - ('Do I Wanna Know?',) tienen un soporte de:  0.0163
# - ("Don't",) tienen un soporte de:  0.0305
# - ("Don't Let Me Down",) tienen un soporte de:  0.0317
# - ("Don't Stop Believin'",) tienen un soporte de:  0.0261
# - ('Down',) tienen un soporte de:  0.0287
# - ('Dream On',) tienen un soporte de:  0.0153
# - ('Drive',) tienen un soporte de:  0.0234
# - ("Drop It Like It's Hot",) tienen un soporte de:  0.0154
# - ('Drops of Jupiter',) tienen un soporte de:  0.0162
# - ('Drowning (feat. Kodak Black)',) tienen un soporte de:  0.0193
# - ('Earned It (Fifty Shades Of Grey)',) tienen un soporte de:  0.019
# - ('Electric Feel',) tienen un soporte de:  0.015
# - ('Electric Love',) tienen un soporte de:  0.0182
# - ('Energy',) tienen un soporte de:  0.0167
# - ('Everyday',) tienen un soporte de:  0.019
# - ('Exchange',) tienen un soporte de:  0.017
# - ('Eye of the Tiger',) tienen un soporte de:  0.0153
# - ("F**kin' Problems",) tienen un soporte de:  0.0228
# - ('Faded',) tienen un soporte de:  0.0185
# - ('Fake Love',) tienen un soporte de:  0.0297
# - ('Famous',) tienen un soporte de:  0.0207
# - ('Fancy',) tienen un soporte de:  0.017
# - ('Fast Car',) tienen un soporte de:  0.0229
# - ('Father Stretch My Hands Pt. 1',) tienen un soporte de:  0.0164
# - ('Feels',) tienen un soporte de:  0.0165
# - ('Fire',) tienen un soporte de:  0.0154
# - ('Flex (Ooh, Ooh, Ooh)',) tienen un soporte de:  0.0164
# - ('Forever',) tienen un soporte de:  0.0321
# - ('G.O.M.D.',) tienen un soporte de:  0.016
# - ('Get Low - Street',) tienen un soporte de:  0.0172
# - ('Ghost',) tienen un soporte de:  0.0161
# - ('Go Flex',) tienen un soporte de:  0.0172
# - ('Gold',) tienen un soporte de:  0.0369
# - ('Gold Digger',) tienen un soporte de:  0.0285
# - ('Gone',) tienen un soporte de:  0.0151
# - ('Gravity',) tienen un soporte de:  0.02
# - ('H.O.L.Y.',) tienen un soporte de:  0.0155
# - ('HUMBLE.',) tienen un soporte de:  0.0465
# - ('Hallelujah',) tienen un soporte de:  0.0268
# - ('Halo',) tienen un soporte de:  0.0194
# - ('HeadBand (feat. 2 Chainz)',) tienen un soporte de:  0.0157
# - ('Heartbeat',) tienen un soporte de:  0.0172
# - ('Heathens',) tienen un soporte de:  0.0223
# - ('Hello',) tienen un soporte de:  0.0289
# - ('Hero',) tienen un soporte de:  0.0184
# - ('Hey There Delilah',) tienen un soporte de:  0.0183
# - ('Hey Ya! - Radio Mix / Club Mix',) tienen un soporte de:  0.0203
# - ('Hey, Soul Sister',) tienen un soporte de:  0.016
# - ('Higher',) tienen un soporte de:  0.0157
# - ("Hips Don't Lie",) tienen un soporte de:  0.0184
# - ('Ho Hey',) tienen un soporte de:  0.0169
# - ('Hold On',) tienen un soporte de:  0.0225
# - ("Hold On, We're Going Home",) tienen un soporte de:  0.0157
# - ('Home',) tienen un soporte de:  0.0454
# - ('Hotel California - Remastered',) tienen un soporte de:  0.0185
# - ('Hotline Bling',) tienen un soporte de:  0.0265
# - ('House Party',) tienen un soporte de:  0.0186
# - ('How Deep Is Your Love',) tienen un soporte de:  0.0159
# - ('How to Save a Life',) tienen un soporte de:  0.0169
# - ('Hurricane',) tienen un soporte de:  0.0284
# - ("I Don't Dance",) tienen un soporte de:  0.0151
# - ("I Don't Fuck With You",) tienen un soporte de:  0.0235
# - ('I Don’t Wanna Live Forever (Fifty Shades Darker) - From "Fifty Shades Darker (Original Motion Picture Soundtrack)"',) tienen un soporte de:  0.0154
# - ('I Feel It Coming',) tienen un soporte de:  0.015
# - ('I Miss You',) tienen un soporte de:  0.0166
# - ('I Took A Pill In Ibiza - Seeb Remix',) tienen un soporte de:  0.0219
# - ('I Want You Back',) tienen un soporte de:  0.019
# - ("I Won't Give Up",) tienen un soporte de:  0.0156
# - ("I'm Yours",) tienen un soporte de:  0.0242
# - ("I'm the One",) tienen un soporte de:  0.0319
# - ('IV. sweatpants',) tienen un soporte de:  0.0184
# - ('Ignition - Remix',) tienen un soporte de:  0.031
# - ('In Da Club',) tienen un soporte de:  0.0169
# - ('In the Name of Love',) tienen un soporte de:  0.0174
# - ('Inside Out',) tienen un soporte de:  0.0151
# - ('Intro',) tienen un soporte de:  0.0215
# - ('Island In The Sun',) tienen un soporte de:  0.0155
# - ('Issues',) tienen un soporte de:  0.017
# - ("It Ain't Me (with Selena Gomez)",) tienen un soporte de:  0.0159
# - ("It Wasn't Me",) tienen un soporte de:  0.0218
# - ("It's A Vibe",) tienen un soporte de:  0.0161
# - ("Jessie's Girl",) tienen un soporte de:  0.0177
# - ('Juke Jam (feat. Justin Bieber & Towkio)',) tienen un soporte de:  0.0153
# - ('Jumpman',) tienen un soporte de:  0.0287
# - ('Jungle',) tienen un soporte de:  0.022
# - ('Kids',) tienen un soporte de:  0.02
# - ('Kiss Me',) tienen un soporte de:  0.0158
# - ('Knee Deep (feat. Jimmy Buffett)',) tienen un soporte de:  0.0157
# - ('LOVE. FEAT. ZACARI.',) tienen un soporte de:  0.0181
# - ('LOYALTY. FEAT. RIHANNA.',) tienen un soporte de:  0.0153
# - ('Landslide',) tienen un soporte de:  0.0176
# - ('Latch',) tienen un soporte de:  0.0158
# - ('Lay Me Down',) tienen un soporte de:  0.0186
# - ('Lean On (feat. MØ & DJ Snake)',) tienen un soporte de:  0.0265
# - ('Let Her Go',) tienen un soporte de:  0.0227
# - ('Let It Go',) tienen un soporte de:  0.0275
# - ('Let Me Love You',) tienen un soporte de:  0.0382
# - ('Little Talks',) tienen un soporte de:  0.0162
# - ("Livin' On A Prayer",) tienen un soporte de:  0.0168
# - ('Location',) tienen un soporte de:  0.0323
# - ('Lose Yourself - Soundtrack Version',) tienen un soporte de:  0.019
# - ('Love Me',) tienen un soporte de:  0.0179
# - ('Love Yourself',) tienen un soporte de:  0.0217
# - ('Low Life',) tienen un soporte de:  0.0237
# - ('Magic',) tienen un soporte de:  0.0151
# - ('Magnolia',) tienen un soporte de:  0.0198
# - ('Maps',) tienen un soporte de:  0.0153
# - ('Mask Off',) tienen un soporte de:  0.0316
# - ('Me, Myself & I',) tienen un soporte de:  0.0245
# - ('Mercy',) tienen un soporte de:  0.0305
# - ('Middle',) tienen un soporte de:  0.0227
# - ('Midnight City',) tienen un soporte de:  0.0168
# - ('Money Longer',) tienen un soporte de:  0.0194
# - ('Monster',) tienen un soporte de:  0.0218
# - ('More Than a Feeling',) tienen un soporte de:  0.0151
# - ('Mr. Brightside',) tienen un soporte de:  0.0248
# - ('Ms. Jackson',) tienen un soporte de:  0.015
# - ('My Girl',) tienen un soporte de:  0.0286
# - ('My House',) tienen un soporte de:  0.0209
# - ('My Way',) tienen un soporte de:  0.0153
# - ('Needed Me',) tienen un soporte de:  0.0238
# - ('Never Be Like You',) tienen un soporte de:  0.023
# - ('Never Forget You',) tienen un soporte de:  0.016
# - ('Ni**as In Paris',) tienen un soporte de:  0.0275
# - ('No Diggity',) tienen un soporte de:  0.0203
# - ('No Hands (feat. Roscoe Dash and Wale) - Explicit Album Version',) tienen un soporte de:  0.0192
# - ('No Problem (feat. Lil Wayne & 2 Chainz)',) tienen un soporte de:  0.0321
# - ('No Role Modelz',) tienen un soporte de:  0.0311
# - ('No Type',) tienen un soporte de:  0.0177
# - ('Numb',) tienen un soporte de:  0.018
# - ('Often',) tienen un soporte de:  0.0163
# - ('One Dance',) tienen un soporte de:  0.0411
# - ('One Night',) tienen un soporte de:  0.0172
# - ('Only',) tienen un soporte de:  0.0163
# - ('Ophelia',) tienen un soporte de:  0.0182
# - ('PILLOWTALK',) tienen un soporte de:  0.016
# - ('POWER',) tienen un soporte de:  0.0152
# - ('Panda',) tienen un soporte de:  0.0307
# - ('Paradise',) tienen un soporte de:  0.0222
# - ('Paris',) tienen un soporte de:  0.0259
# - ('Party In The U.S.A.',) tienen un soporte de:  0.0211
# - ('Passionfruit',) tienen un soporte de:  0.0254
# - ('Perfect',) tienen un soporte de:  0.0199
# - ('Photograph',) tienen un soporte de:  0.0218
# - ('Piano Man',) tienen un soporte de:  0.0163
# - ('Planez',) tienen un soporte de:  0.016
# - ('Play It Again',) tienen un soporte de:  0.019
# - ('Pompeii',) tienen un soporte de:  0.0186
# - ('Pony',) tienen un soporte de:  0.0156
# - ('Pop Style',) tienen un soporte de:  0.0181
# - ('Portland',) tienen un soporte de:  0.0172
# - ('Promiscuous',) tienen un soporte de:  0.016
# - ('Promise',) tienen un soporte de:  0.0171
# - ('Pumped Up Kicks',) tienen un soporte de:  0.0185
# - ('Radioactive',) tienen un soporte de:  0.0229
# - ('Rather Be (feat. Jess Glynne)',) tienen un soporte de:  0.0176
# - ('Redbone',) tienen un soporte de:  0.0281
# - ('Rich Girl',) tienen un soporte de:  0.0159
# - ('Ride',) tienen un soporte de:  0.0414
# - ('Riptide',) tienen un soporte de:  0.0332
# - ('River',) tienen un soporte de:  0.0151
# - ('Rolex',) tienen un soporte de:  0.0161
# - ('Roses',) tienen un soporte de:  0.0424
# - ('Runaway',) tienen un soporte de:  0.018
# - ('Runaway (U & I)',) tienen un soporte de:  0.0156
# - ('Sail',) tienen un soporte de:  0.0187
# - ('Santeria',) tienen un soporte de:  0.0172
# - ('Say It',) tienen un soporte de:  0.0271
# - ('Say My Name',) tienen un soporte de:  0.0266
# - ('Say Something',) tienen un soporte de:  0.0156
# - ("Say You Won't Let Go",) tienen un soporte de:  0.02
# - ('Secrets',) tienen un soporte de:  0.0173
# - ('See You Again (feat. Charlie Puth) - From "Furious 7"',) tienen un soporte de:  0.0151
# - ('Selfish',) tienen un soporte de:  0.0242
# - ('September',) tienen un soporte de:  0.0259
# - ('Seven Nation Army',) tienen un soporte de:  0.0174
# - ('Shape of You',) tienen un soporte de:  0.031
# - ('She Will Be Loved - Radio Mix',) tienen un soporte de:  0.0184
# - ('Shut Up and Dance',) tienen un soporte de:  0.0222
# - ('Side To Side',) tienen un soporte de:  0.0154
# - ('Skinny Love',) tienen un soporte de:  0.0257
# - ('Slide',) tienen un soporte de:  0.0318
# - ('Slippery (feat. Gucci Mane)',) tienen un soporte de:  0.0236
# - ('Slow Motion',) tienen un soporte de:  0.0184
# - ('Smells Like Teen Spirit',) tienen un soporte de:  0.0163
# - ('Smile',) tienen un soporte de:  0.0172
# - ('Sober',) tienen un soporte de:  0.0247
# - ('Someday',) tienen un soporte de:  0.0154
# - ('Something Just Like This',) tienen un soporte de:  0.0216
# - ('Sorry',) tienen un soporte de:  0.0318
# - ('Sorry Not Sorry',) tienen un soporte de:  0.0183
# - ('Springsteen',) tienen un soporte de:  0.0161
# - ('Starboy',) tienen un soporte de:  0.0281
# - ('Starving',) tienen un soporte de:  0.0181
# - ('Stay',) tienen un soporte de:  0.0339
# - ('Stay (with Alessia Cara)',) tienen un soporte de:  0.0212
# - ('Stay With Me',) tienen un soporte de:  0.0194
# - ('Stitches',) tienen un soporte de:  0.0171
# - ('Stolen Dance',) tienen un soporte de:  0.019
# - ('Stressed Out',) tienen un soporte de:  0.0223
# - ('Strip That Down',) tienen un soporte de:  0.015
# - ('Stronger',) tienen un soporte de:  0.0258
# - ('Sugar',) tienen un soporte de:  0.0203
# - ('Summer',) tienen un soporte de:  0.0202
# - ('Summertime',) tienen un soporte de:  0.0164
# - ('Sunday Morning',) tienen un soporte de:  0.0163
# - ('Swang',) tienen un soporte de:  0.0219
# - ('Sweater Weather',) tienen un soporte de:  0.018
# - ('Sweet Caroline',) tienen un soporte de:  0.0171
# - ("Sweet Child O' Mine",) tienen un soporte de:  0.0205
# - ('Sweet Home Alabama',) tienen un soporte de:  0.0207
# - ('Swimming Pools (Drank)',) tienen un soporte de:  0.0173
# - ('T-Shirt',) tienen un soporte de:  0.0351
# - ('Take Me To Church',) tienen un soporte de:  0.0195
# - ('Take Your Time',) tienen un soporte de:  0.0163
# - ("That's What I Like",) tienen un soporte de:  0.0261
# - ('The Hills',) tienen un soporte de:  0.0273
# - ('The Motto',) tienen un soporte de:  0.0152
# - ('The Ocean',) tienen un soporte de:  0.015
# - ('The Scientist',) tienen un soporte de:  0.0156
# - ('Thinkin Bout You',) tienen un soporte de:  0.0186
# - ('Thinking Out Loud',) tienen un soporte de:  0.0234
# - ('This Could Be Us',) tienen un soporte de:  0.0161
# - ('This Is What You Came For',) tienen un soporte de:  0.0215
# - ('Thunder',) tienen un soporte de:  0.0188
# - ('Timber',) tienen un soporte de:  0.0155
# - ('Toes',) tienen un soporte de:  0.0159
# - ('Too Good',) tienen un soporte de:  0.0202
# - ('Trap Queen',) tienen un soporte de:  0.0289
# - ('Trouble',) tienen un soporte de:  0.0216
# - ('Tunnel Vision',) tienen un soporte de:  0.0247
# - ('Under The Bridge',) tienen un soporte de:  0.0155
# - ('Unforgettable',) tienen un soporte de:  0.0326
# - ('Uptown Funk',) tienen un soporte de:  0.0231
# - ('V. 3005',) tienen un soporte de:  0.0221
# - ('Wagon Wheel',) tienen un soporte de:  0.0234
# - ('Wake Me Up - Radio Edit',) tienen un soporte de:  0.0168
# - ('Wake Up',) tienen un soporte de:  0.0212
# - ('Wasted',) tienen un soporte de:  0.017
# - ('Water',) tienen un soporte de:  0.0174
# - ('Waves',) tienen un soporte de:  0.0242
# - ('Weak',) tienen un soporte de:  0.0172
# - ('Wet Dreamz',) tienen un soporte de:  0.0189
# - ('What Do You Mean?',) tienen un soporte de:  0.0216
# - ('What They Want',) tienen un soporte de:  0.0175
# - ('Where Are Ü Now (with Justin Bieber)',) tienen un soporte de:  0.0199
# - ('White Iverson',) tienen un soporte de:  0.0304
# - ('Wild Thoughts',) tienen un soporte de:  0.0188
# - ('With You',) tienen un soporte de:  0.0222
# - ('Wonderwall - Remastered',) tienen un soporte de:  0.0181
# - ('Work',) tienen un soporte de:  0.0261
# - ('Work from Home',) tienen un soporte de:  0.0217
# - ('X (feat. Future)',) tienen un soporte de:  0.0204
# - ('XO',) tienen un soporte de:  0.0171
# - ('XO TOUR Llif3',) tienen un soporte de:  0.0323
# - ('Yeah!',) tienen un soporte de:  0.0238
# - ('You',) tienen un soporte de:  0.0233
# - ('You & Me',) tienen un soporte de:  0.0176
# - ('You Make My Dreams - Remastered',) tienen un soporte de:  0.0159
# - ('You Was Right',) tienen un soporte de:  0.0194
# - ('Young Dumb & Broke',) tienen un soporte de:  0.0219
# - ('Young, Wild & Free (feat. Bruno Mars) - feat. Bruno Mars',) tienen un soporte de:  0.0175
# - ('Your Song',) tienen un soporte de:  0.0161
# - ('goosebumps',) tienen un soporte de:  0.0308
# - ("i hate u, i love u (feat. olivia o'brien)",) tienen un soporte de:  0.02
# - ('iSpy (feat. Lil Yachty)',) tienen un soporte de:  0.0331
# - ('m.A.A.d city',) tienen un soporte de:  0.0169
# - ('oui',) tienen un soporte de:  0.0183
# - ('pick up the phone',) tienen un soporte de:  0.0196
# - ('rockstar',) tienen un soporte de:  0.0232
# ========== Itemsets de  2 elementos ==========
# - ('Bounce Back', 'Bad and Boujee (feat. Lil Uzi Vert)') tienen un soporte de:  0.0169
# - ('Broccoli (feat. Lil Yachty)', 'Bad and Boujee (feat. Lil Uzi Vert)') tienen un soporte de:  0.0155
# - ('Caroline', 'Bad and Boujee (feat. Lil Uzi Vert)') tienen un soporte de:  0.0153
# - ('Caroline', 'Broccoli (feat. Lil Yachty)') tienen un soporte de:  0.0172
# - ('Closer', 'Let Me Love You') tienen un soporte de:  0.0159
# - ('HUMBLE.', 'Bad and Boujee (feat. Lil Uzi Vert)') tienen un soporte de:  0.0167
# - ('HUMBLE.', 'Bounce Back') tienen un soporte de:  0.0156
# - ('HUMBLE.', 'Congratulations') tienen un soporte de:  0.0214
# - ('HUMBLE.', 'DNA.') tienen un soporte de:  0.019
# - ('HUMBLE.', 'Mask Off') tienen un soporte de:  0.0204
# - ('HUMBLE.', 'XO TOUR Llif3') tienen un soporte de:  0.0204
# - ('HUMBLE.', 'goosebumps') tienen un soporte de:  0.0167
# - ('HUMBLE.', 'iSpy (feat. Lil Yachty)') tienen un soporte de:  0.0155
# - ('Mask Off', 'Bad and Boujee (feat. Lil Uzi Vert)') tienen un soporte de:  0.0151
# - ('Mask Off', 'Congratulations') tienen un soporte de:  0.0162
# - ('No Problem (feat. Lil Wayne & 2 Chainz)', 'Broccoli (feat. Lil Yachty)') tienen un soporte de:  0.0158
# - ('XO TOUR Llif3', 'Congratulations') tienen un soporte de:  0.0179
# - ('XO TOUR Llif3', 'Mask Off') tienen un soporte de:  0.0163
# - ('XO TOUR Llif3', 'goosebumps') tienen un soporte de:  0.0152
# - ('goosebumps', 'Congratulations') tienen un soporte de:  0.0155
# - ('iSpy (feat. Lil Yachty)', 'Bad and Boujee (feat. Lil Uzi Vert)') tienen un soporte de:  0.0152
# - ('iSpy (feat. Lil Yachty)', 'Congratulations') tienen un soporte de:  0.0162

# %% [markdown]
# ## Reglas de asociacion

# %%
def getReglasdeAsociacion(itemsetsFrecuentes,minConfianza,minLift):
  Reglas=[]
  confianzas=[]
  lifts=[]
  #empezamos a recorrer los itemsets de manera inversa para tener los itemsets de mayor tamaño
  # diccionario de suport
  suportDict={}
  for nivel in itemsetsFrecuentes:
    for elemento in nivel:
      suportDict[elemento[0]]=len(elemento[1])/10000
  tamañoMax=len(itemsets)-1
  
  while(tamañoMax>=1):
    for itemset in itemsets[tamañoMax]:
      combinaciones=list(combinations(itemset[0],tamañoMax))
      for combinacion in combinaciones:
        confianza=suportDict[itemset[0]]/suportDict[combinacion]
        diferencia=tuple(set(itemset[0]).difference(set(combinacion)))
        lift=suportDict[itemset[0]]/(suportDict[combinacion]*suportDict[diferencia])
        #print(lift)
        if(confianza>=minConfianza and lift>minLift):
          Reglas.append([combinacion,diferencia])
          confianzas.append(confianza)
          lifts.append(lift)
    tamañoMax-=1
  listaFinal=[]
  for i in range(len(Reglas)):
    aux=[Reglas[i],confianzas[i],lifts[i]]
    listaFinal.append(aux)
  return listaFinal

# %% [markdown]
# ## Calculamos las reglas de asociacion

# %%
reglas=getReglasdeAsociacion(itemsets,0.51,11)

# %% [markdown]
# ### Mostramos las reglas junto a su confianza y lift

# %%
for i in range(len(reglas)):
    print("====== Regla ",i+1," ======")
    print("regla: ",reglas[i][0][0],"->",reglas[i][0][1])
    print("confianza: ",reglas[i][1])
    print("lift: ",reglas[i][2])
# Out:
# ====== Regla  1  ======
# regla:  ('Bounce Back',) -> ('Bad and Boujee (feat. Lil Uzi Vert)',)
# confianza:  0.569023569023569
# lift:  16.493436783291852
# ====== Regla  2  ======
# regla:  ('Bounce Back',) -> ('HUMBLE.',)
# confianza:  0.5252525252525252
# lift:  11.295753231237102
# ====== Regla  3  ======
# regla:  ('Congratulations',) -> ('HUMBLE.',)
# confianza:  0.531017369727047
# lift:  11.41972838122682
# ====== Regla  4  ======
# regla:  ('DNA.',) -> ('HUMBLE.',)
# confianza:  0.8225108225108225
# lift:  17.68840478517898
# ====== Regla  5  ======
# regla:  ('Mask Off',) -> ('HUMBLE.',)
# confianza:  0.6455696202531646
# lift:  13.883217639853001
# ====== Regla  6  ======
# regla:  ('XO TOUR Llif3',) -> ('HUMBLE.',)
# confianza:  0.631578947368421
# lift:  13.582342954159593
# ====== Regla  7  ======
# regla:  ('goosebumps',) -> ('HUMBLE.',)
# confianza:  0.5422077922077921
# lift:  11.660382628124562
# ====== Regla  8  ======
# regla:  ('Mask Off',) -> ('Congratulations',)
# confianza:  0.5126582278481012
# lift:  12.721047837421864
# ====== Regla  9  ======
# regla:  ('XO TOUR Llif3',) -> ('Congratulations',)
# confianza:  0.5541795665634675
# lift:  13.751354009019042
# ====== Regla  10  ======
# regla:  ('Mask Off',) -> ('XO TOUR Llif3',)
# confianza:  0.5158227848101264
# lift:  15.969745659756237

# %% [markdown]
# # Conclusiones e interpretaciones

# %% [markdown]
# las reglas encontradas cumplen con la condicion de que todas las asociaciones son artistas de rap y
# el que tiene mayor confianza indica de que el cantantees el compositor de las dos canciones
